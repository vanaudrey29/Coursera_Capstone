# %% [markdown]
# CAPSTONE PROJECT:
# ======

# %% [markdown]
# ## Trending locations closest to bike-sharing docking stations

# %% [markdown]
# ### I. Introduction

# %% [markdown]
# As people are becoming more health and environmentally conscious, shared biking systems in metropolitan areas have become increasingly more popular over the years, with a steady increase in the number of users and docking stations.
#
# Being a past user myself, I would always map out my routes ahead of time and made sure to check out what was nearby my destination station. Knowing the city, this task is easy. However, what if you are a visitor in a city and don’t know where to go or what to do? Wouldn’t it be great to have an easy way to find out the docking stations that have the highest number popular venues/activities in order to maximize your time within a new city you wish to discover?
#
# For this capstone project, I will take a look at the most trending venues/activities within a 100 meter radius of a docking station in the city of Montreal. This information is useful for tourists visiting the city, who wish to discover the city using the shared-biking system Bixi, and are time-limited. However, the methodology used to discover the most trending locations in Montreal can be applied to other cities with a bike-sharing system such as Bixi. So the question to be answered through this project is:
#
# What are the docking station locations in the city of Montreal that have the most trending venues/activities nearby?

# %% [markdown]
# ### II. Data

# %% [markdown]
# The dataset that will be required to answer the question stated in the introduction includes the locations of the docking stations, which is open data available on the Bixi website of Montreal in .csv format. The .csv file contains the most recent list of the docking stations in 2019 for the Bixi bikes, with details about each station (station code, station name, latitude and longitude). This information can be downloaded from the Bixi website: https://www.bixi.com/en/open-data.
#
# Foursquare location data will be used as well to determine the most popular venues/activities in the city of Montreal. The location data will then be used to determine the most trending venues within a 100 m radius of each of the Bixi docking station locations provided in the Bixi dataset. The venues will then be analyzed by location in order to determine the docking station locations with the most trending venues. As a final result, the venues will be clustered by location using *k-means clustering* and will then be mapped by cluster along with the nearest Bixi docking station.

# %% [markdown]
# #### Let's begin with importing the data from the Bixi website and saving it to a dataframe named *stations_df*.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %%
stations_df = pd.read_csv('data/Stations_2019.csv')
stations_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5065872854d0> in <module>
# ----> 1 stations_df = pd.read_csv('data/Stations_2019.csv')
#       2 stations_df
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'data/Stations_2019.csv' does not exist: b'data/Stations_2019.csv'

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#     Code                                    name   latitude  longitude
# 0  10002  Métro Charlevoix (Centre / Charlevoix)  45.478228 -73.569651
# 1   4000                  Jeanne-d'Arc / Ontario  45.549598 -73.541874
# 2   4001                     Graham / Brookfield  45.520075 -73.629776
# 3   4002                      Graham / Wicksteed  45.516937 -73.640483
# 4   5002                St-Charles / Montarville  45.533682 -73.515261
# (615, 4)

# %% [markdown]
# As we can see there are a total of 615 docking stations for Bixi bikes in the Montreal area.

# %% [markdown]
# #### Next, we'll use geopy library to get the latitude and longitude values of the city of Montreal.

# %%
# import necessary libraries
import json
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
# !pip install folium
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-0                   --> 2019.6.16-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_0              --> 2019.6.16-py36_1     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1c-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/4f/86/1ab30184cb60bc2b95deffe2bd86b8ddbab65a4fac9f7313c278c6e8d049/folium-0.9.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 874kB/s eta 0:00:01
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2019.6.16)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.9.1

# %%
mtl_address = 'Montreal, QC'

geolocator = Nominatim(user_agent="mtl_explorer")
mtl_location = geolocator.geocode(mtl_address)
mtl_latitude = mtl_location.latitude
mtl_longitude = mtl_location.longitude
print('The geographical coordinates of the city of Montreal are {}, {}.'.format(mtl_latitude, mtl_longitude))
# Out:
# The geographical coordinates of the city of Montreal are 45.4972159, -73.6103642.

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the trending venues in Montreal and segment them.

# %% [markdown]
# #### First, let's define Foursquare Credentials and Version.

# %%
CLIENT_ID = 'SAWYPKIV3SELVRC0KO1GJ3PRKETDQ3AXYAYYG10JQT0P2I4O'
CLIENT_SECRET = 'VUOM0J4N1XKS1FLKASWEL44AIJIQCI3MY2LF5CEWVKRCSTKC'
VERSION = '20190722'

# %% [markdown]
# #### Let's get the top 500 **trending** venues within a 20 km radius of Montreal center.

# %%
limit = 500
radius = 20000
section = 'trending'
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, mtl_latitude, mtl_longitude, VERSION, radius, limit, section)

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d370a1523bb8e002c0d7338'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Montreal',
#   'headerFullLocation': 'Montreal',
#   'headerLocationGranularity': 'city',
#   'totalResults': 244,
#   'suggestedBounds': {'ne': {'lat': 45.67721608000018,
#     'lng': -73.35404683487533},
#    'sw': {'lat': 45.31721571999982, 'lng': -73.86668156512468}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad8f749f964a520871621e3',
#        'name': 'Parc du Mont-Royal',
#        'location': {'address': '1260 Chemin Remembrance',
#         'lat': 45.50407921694641,
#         'lng': -73.58732075575296,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50407921694641,
#           'lng': -73.58732075575296}],
#         'distance': 1953,
#         'postalCode': 'H3H 1A2',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1260 Chemin Remembrance',
#          'Montréal QC H3H 1A2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad8f749f964a520871621e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06ff964a5208afb20e3',
#        'name': 'CEPSUM',
#        'location': {'address': '2100 boul. Édouard-Montpetit',
#         'lat': 45.508319610042015,
#         'lng': -73.61266416211244,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.508319610042015,
#           'lng': -73.61266416211244}],
#         'distance': 1249,
#         'postalCode': 'H3T 1J4',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['2100 boul. Édouard-Montpetit',
#          'Montréal QC H3T 1J4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1b2941735',
#          'name': 'College Gym',
#          'pluralName': 'College Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c06ff964a5208afb20e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1b4905f964a5208bfa23e3',
#        'name': 'Parc Westmount Park',
#        'location': {'address': 'Parc Westmount',
#         'lat': 45.48157356036293,
#         'lng': -73.59747648239136,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.48157356036293,
#           'lng': -73.59747648239136}],
#         'distance': 2010,
#         'cc': 'CA',
#         'city': 'Westmount',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['Parc Westmount', 'Westmount QC', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1b4905f964a5208bfa23e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd6eeddaeb1224b49fc2aff',
#        'name': 'Chalet du Mont-Royal',
#        'location': {'address': '1196 voie Camillien-Houde',
#         'crossStreet': 'Parc du Mont-Royal',
#         'lat': 45.50363643973105,
#         'lng': -73.58709498837177,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50363643973105,
#           'lng': -73.58709498837177}],
#         'distance': 1951,
#         'postalCode': 'H3H 1A2',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1196 voie Camillien-Houde (Parc du Mont-Royal)',
#          'Montréal QC H3H 1A2',
#          'Canada']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd6eeddaeb1224b49fc2aff-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e356969b61cddd1cd3cbba3',
#        'name': 'Musée des beaux-arts de Montréal (MBAM)',
#        'location': {'address': '1380 rue Sherbrooke O',
#         'crossStreet': 'coin du Musée',
#         'lat': 45.498436,
#         'lng': -73.579715,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.498436,
#           'lng': -73.579715}],
#         'distance': 2395,
#         'postalCode': 'H3G 1J5',
#         'cc': 'CA',
#         'neighborhood': 'Ville-Marie',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1380 rue Sherbrooke O (coin du Musée)',
#          'Montréal QC H3G 1J5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e356969b61cddd1cd3cbba3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd18a1f9854d13a45abf94d',
#        'name': 'Moksha Yoga NDG',
#        'location': {'address': '4260 Ave. Girouard, 3rd Floor',
#         'crossStreet': 'Monkland',
#         'lat': 45.47660580955393,
#         'lng': -73.62149820061569,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.47660580955393,
#           'lng': -73.62149820061569}],
#         'distance': 2453,
#         'postalCode': 'H4A 3C9',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['4260 Ave. Girouard, 3rd Floor (Monkland)',
#          'Montréal QC H4A 3C9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd18a1f9854d13a45abf94d-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ceeb44951785941ad06bd8f',
#        'name': 'La Panthère Verte',
#        'location': {'address': '2153 MacKay St',
#         'crossStreet': 'de Maisonneuve Blvd West',
#         'lat': 45.497335,
#         'lng': -73.580144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.497335,
#           'lng': -73.580144}],
#         'distance': 2358,
#         'postalCode': 'H3G 2J2',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['2153 MacKay St (de Maisonneuve Blvd West)',
#          'Montréal QC H3G 2J2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ceeb44951785941ad06bd8f-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4e3966f964a520e3e526e3',
#        'name': 'Midtown Le Sporting Club Sanctuaire',
#        'location': {'address': '6105 avenue du Boisé',
#         'crossStreet': 'at avenue Van Horne',
#         'lat': 45.51109421929828,
#         'lng': -73.6211914015921,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51109421929828,
#           'lng': -73.6211914015921}],
#         'distance': 1760,
#         'postalCode': 'H3S 2V9',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['6105 avenue du Boisé (at avenue Van Horne)',
#          'Montréal QC H3S 2V9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '59721110'}},
#       'referralId': 'e-0-4b4e3966f964a520e3e526e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fcabb93e4b00865cc6a7159',
#        'name': 'Maison Boulud',
#        'location': {'address': '1228 Rue Sherbrooke Ouest',
#         'crossStreet': 'entre Drummond & De la Montagne',
#         'lat': 45.50006167830259,
#         'lng': -73.57832360975108,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50006167830259,
#           'lng': -73.57832360975108}],
#         'distance': 2519,
#         'postalCode': 'H3G 1H7',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1228 Rue Sherbrooke Ouest (entre Drummond & De la Montagne)',
#          'Montréal QC H3G 1H7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '68697293'}},
#       'referralId': 'e-0-4fcabb93e4b00865cc6a7159-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c069f964a520aef820e3',
#        'name': 'The Ritz-Carlton Montréal',
#        'location': {'address': '1228 Sherbrooke St.West',
#         'lat': 45.500190834049214,
#         'lng': -73.5781265781752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.500190834049214,
#           'lng': -73.5781265781752}],
#         'distance': 2537,
#         'postalCode': 'H3G 1H6',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1228 Sherbrooke St.West',
#          'Montréal QC H3G 1H6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c069f964a520aef820e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f664b09e4b0c7552e860a3c',
#        'name': 'Tiffany & Co.',
#        'location': {'address': '1290 Sherbrooke Street West',
#         'lat': 45.499782350294616,
#         'lng': -73.5784032940864,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.499782350294616,
#           'lng': -73.5784032940864}],
#         'distance': 2510,
#         'postalCode': 'H3G 1H5',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1290 Sherbrooke Street West',
#          'Montréal QC H3G 1H5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111951735',
#          'name': 'Jewelry Store',
#          'pluralName': 'Jewelry Stores',
#          'shortName': 'Jewelry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f664b09e4b0c7552e860a3c-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a86753498ee54a8b686b1e',
#        'name': 'Damas',
#        'location': {'address': '1201 Van Horne',
#         'lat': 45.52259571712413,
#         'lng': -73.61311244738047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52259571712413,
#           'lng': -73.61311244738047}],
#         'distance': 2833,
#         'postalCode': 'H2V 1K4',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1201 Van Horne',
#          'Montréal QC H2V 1K4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a86753498ee54a8b686b1e-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5839f226a6118c60b52b2f54',
#        'name': 'Café Pacefika',
#        'location': {'address': '1443 rue Lambert Closse',
#         'crossStreet': 'Maisonneuve',
#         'lat': 45.490514,
#         'lng': -73.584091,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.490514,
#           'lng': -73.584091}],
#         'distance': 2181,
#         'postalCode': 'H2H 1Z5',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1443 rue Lambert Closse (Maisonneuve)',
#          'Montréal QC H2H 1Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5839f226a6118c60b52b2f54-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b648d42f964a520f0bc2ae3',
#        'name': 'Belvédère Kondiaronk',
#        'location': {'address': 'Parc du Mont-Royal',
#         'lat': 45.503440129643565,
#         'lng': -73.58678512301853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.503440129643565,
#           'lng': -73.58678512301853}],
#         'distance': 1965,
#         'postalCode': 'H3H 1A1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['Parc du Mont-Royal',
#          'Montréal QC H3H 1A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b648d42f964a520f0bc2ae3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba2a760f964a520f50c38e3',
#        'name': 'Kazu',
#        'location': {'address': '1862 rue Ste-Catherine O.',
#         'crossStreet': 'coin St-Marc',
#         'lat': 45.493013703554944,
#         'lng': -73.58020256600203,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.493013703554944,
#           'lng': -73.58020256600203}],
#         'distance': 2399,
#         'postalCode': 'H3H 1M1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1862 rue Ste-Catherine O. (coin St-Marc)',
#          'Montréal QC H3H 1M1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba2a760f964a520f50c38e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55553204498eb09323efdc86',
#        'name': "Mandy's",
#        'location': {'address': '2067 Crescent',
#         'lat': 45.49828577282335,
#         'lng': -73.57789545259563,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.49828577282335,
#           'lng': -73.57789545259563}],
#         'distance': 2536,
#         'postalCode': 'H3G 2C1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['2067 Crescent',
#          'Montréal QC H3G 2C1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55553204498eb09323efdc86-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9ae085f964a520a7de35e3',
#        'name': 'La Buvette chez Simone',
#        'location': {'address': '4869 ave. du Parc',
#         'crossStreet': 'entre Villeneuve & St-Joseph',
#         'lat': 45.51870843852072,
#         'lng': -73.59360292330558,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51870843852072,
#           'lng': -73.59360292330558}],
#         'distance': 2726,
#         'postalCode': 'H2V 4K7',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['4869 ave. du Parc (entre Villeneuve & St-Joseph)',
#          'Montréal QC H2V 4K7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9ae085f964a520a7de35e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06df964a52077fa20e3',
#        'name': 'Milos',
#        'location': {'address': '5357 avenue du Parc',
#         'crossStreet': 'entre St-Viateur & Fairmount',
#         'lat': 45.521541755219125,
#         'lng': -73.6006290626032,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.521541755219125,
#           'lng': -73.6006290626032}],
#         'distance': 2812,
#         'postalCode': 'H2V 4G9',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['5357 avenue du Parc (entre St-Viateur & Fairmount)',
#          'Montréal QC H2V 4G9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c06df964a52077fa20e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ade5847f964a520337521e3',
#        'name': 'Le Glacier Bilboquet',
#        'location': {'address': '1311 ave. Bernard Ouest',
#         'crossStreet': 'coin Outremont',
#         'lat': 45.51899327690843,
#         'lng': -73.60973668356114,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51899327690843,
#           'lng': -73.60973668356114}],
#         'distance': 2424,
#         'postalCode': 'H2V 1W1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1311 ave. Bernard Ouest (coin Outremont)',
#          'Montréal QC H2V 1W1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ade5847f964a520337521e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5f7b80f964a520fbbc29e3',
#        'name': 'Mamie Clafoutis',
#        'location': {'address': '1291 ave. Van Horne',
#         'crossStreet': 'coin av. Outremont',
#         'lat': 45.521466330787135,
#         'lng': -73.61399829440643,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.521466330787135,
#           'lng': -73.61399829440643}],
#         'distance': 2714,
#         'postalCode': 'H2V 1K5',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1291 ave. Van Horne (coin av. Outremont)',
#          'Montréal QC H2V 1K5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5f7b80f964a520fbbc29e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea05136775ba9493a7a8f9c',
#        'name': 'Enso Yoga',
#        'location': {'address': '1470 Peel St., Suite 100',
#         'crossStreet': 'de Maisonneuve West',
#         'lat': 45.500742817766216,
#         'lng': -73.57494341962236,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.500742817766216,
#           'lng': -73.57494341962236}],
#         'distance': 2791,
#         'postalCode': 'H3A 1T1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1470 Peel St., Suite 100 (de Maisonneuve West)',
#          'Montréal QC H3A 1T1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ea05136775ba9493a7a8f9c-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06ff964a5205ffb20e3',
#        'name': 'Drawn & Quarterly',
#        'location': {'address': '211 rue Bernard Ouest',
#         'lat': 45.52474756423502,
#         'lng': -73.60461449677928,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52474756423502,
#           'lng': -73.60461449677928}],
#         'distance': 3097,
#         'postalCode': 'H2T 2K5',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['211 rue Bernard Ouest',
#          'Montréal QC H2T 2K5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c06ff964a5205ffb20e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06ff964a52026fb20e3',
#        'name': 'St-Viateur Bagel (La Maison du Bagel)',
#        'location': {'address': '263 rue Saint-Viateur Ouest',
#         'crossStreet': 'entre Jeanne-Mance & du Parc',
#         'lat': 45.522572739028064,
#         'lng': -73.60187802838894,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.522572739028064,
#           'lng': -73.60187802838894}],
#         'distance': 2899,
#         'postalCode': 'H2V 1Y1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['263 rue Saint-Viateur Ouest (entre Jeanne-Mance & du Parc)',
#          'Montréal QC H2V 1Y1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'shortName': 'Bagels',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c06ff964a52026fb20e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dcc2d9bd22d480bd644dedd',
#        'name': 'Kem CoBa',
#        'location': {'address': '60 Fairmount Ouest',
#         'crossStreet': '@ Clark',
#         'lat': 45.523112298179306,
#         'lng': -73.59516982457566,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.523112298179306,
#           'lng': -73.59516982457566}],
#         'distance': 3116,
#         'postalCode': 'H2T 2M2',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['60 Fairmount Ouest (@ Clark)',
#          'Montréal QC H2T 2M2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dcc2d9bd22d480bd644dedd-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af81956f964a520fa0a22e3',
#        'name': 'Club Sportif MAA',
#        'location': {'address': '2070 rue Peel',
#         'crossStreet': 'Sherbrooke',
#         'lat': 45.50070025610725,
#         'lng': -73.57481746102465,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50070025610725,
#           'lng': -73.57481746102465}],
#         'distance': 2800,
#         'postalCode': 'H3A 1W6',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['2070 rue Peel (Sherbrooke)',
#          'Montréal QC H3A 1W6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af81956f964a520fa0a22e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5753b13d498e0bb79b5907c4',
#        'name': 'Noren\u3000のれん',
#        'location': {'address': '77, rue Rue Rachel Ouest',
#         'crossStreet': 'entre Clark & St-Urbain',
#         'lat': 45.517026020420396,
#         'lng': -73.58260758456034,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.517026020420396,
#           'lng': -73.58260758456034}],
#         'distance': 3090,
#         'postalCode': 'H2W 1G2',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['77, rue Rue Rachel Ouest (entre Clark & St-Urbain)',
#          'Montréal QC H2W 1G2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5753b13d498e0bb79b5907c4-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aea6fd9f964a52094bb21e3',
#        'name': 'Leméac',
#        'location': {'address': '1045 Av. Laurier O',
#         'crossStreet': 'coin Durocher',
#         'lat': 45.51819059718181,
#         'lng': -73.5973042421044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51819059718181,
#           'lng': -73.5973042421044}],
#         'distance': 2547,
#         'postalCode': 'H2V 2L1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1045 Av. Laurier O (coin Durocher)',
#          'Montréal QC H2V 2L1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aea6fd9f964a52094bb21e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06bf964a5203df920e3',
#        'name': 'Dieu du Ciel!',
#        'location': {'address': '29 ave. Laurier Ouest',
#         'crossStreet': 'coin Saint-Laurent',
#         'lat': 45.522619264275804,
#         'lng': -73.59340457951062,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.522619264275804,
#           'lng': -73.59340457951062}],
#         'distance': 3122,
#         'postalCode': 'H2T 2N2',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['29 ave. Laurier Ouest (coin Saint-Laurent)',
#          'Montréal QC H2T 2N2',
#          'Canada']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c06bf964a5203df920e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58c8b974951e7d7e08bc6fd8',
#        'name': 'Darling',
#        'location': {'address': '4328, Boulevard Saint-Laurent',
#         'crossStreet': 'Marie-Anne',
#         'lat': 45.51899503345051,
#         'lng': -73.58406139558292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51899503345051,
#           'lng': -73.58406139558292}],
#         'distance': 3176,
#         'postalCode': 'H2W 1Z3',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['4328, Boulevard Saint-Laurent (Marie-Anne)',
#          'Montréal QC H2W 1Z3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58c8b974951e7d7e08bc6fd8-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1946b0d4d9c928c4b8f029',
#        'name': 'Tuck Shop',
#        'location': {'address': '4662, rue Notre-Dame Ouest',
#         'crossStreet': 'De Courcelles',
#         'lat': 45.47305167697517,
#         'lng': -73.58852526912918,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.47305167697517,
#           'lng': -73.58852526912918}],
#         'distance': 3184,
#         'postalCode': 'H4C 1S7',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['4662, rue Notre-Dame Ouest (De Courcelles)',
#          'Montréal QC H4C 1S7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1946b0d4d9c928c4b8f029-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9e26b58afca09389c5fd15',
#        'name': 'Boulangerie Guillaume',
#        'location': {'address': '5132 boulevard St-Laurent',
#         'crossStreet': 'Fairmount',
#         'lat': 45.52340491954247,
#         'lng': -73.59366234378703,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52340491954247,
#           'lng': -73.59366234378703}],
#         'distance': 3193,
#         'postalCode': 'H2T 1R8',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['5132 boulevard St-Laurent (Fairmount)',
#          'Montréal QC H2T 1R8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9e26b58afca09389c5fd15-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55fa0f36498ee6e565648d5a',
#        'name': 'Frank & Oak',
#        'location': {'address': '1420, rue Stanley',
#         'crossStreet': 'entre De Maisonneuve & Ste-Catherine',
#         'lat': 45.499572715055805,
#         'lng': -73.574327933144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.499572715055805,
#           'lng': -73.574327933144}],
#         'distance': 2824,
#         'postalCode': 'H3A 1P7',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1420, rue Stanley (entre De Maisonneuve & Ste-Catherine)',
#          'Montréal QC H3A 1P7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d106951735',
#          'name': "Men's Store",
#          'pluralName': "Men's Stores",
#          'shortName': "Men's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55fa0f36498ee6e565648d5a-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b59d9f0f964a520e79b28e3',
#        'name': 'Dominion Square Tavern',
#        'location': {'address': '1243 rue Metcalfe',
#         'crossStreet': 'entre Ste-Catherine & René-Lévesque',
#         'lat': 45.50040540450307,
#         'lng': -73.57163553893498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50040540450307,
#           'lng': -73.57163553893498}],
#         'distance': 3042,
#         'postalCode': 'H3B 2V5',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1243 rue Metcalfe (entre Ste-Catherine & René-Lévesque)',
#          'Montréal QC H3B 2V5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '53684936'}},
#       'referralId': 'e-0-4b59d9f0f964a520e79b28e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06cf964a520eaf920e3',
#        'name': 'Parc Jeanne-Mance',
#        'location': {'address': 'Parc Jeanne-Mance',
#         'lat': 45.516463198402775,
#         'lng': -73.5842749356079,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.516463198402775,
#           'lng': -73.5842749356079}],
#         'distance': 2955,
#         'postalCode': 'H2J 2J9',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['Parc Jeanne-Mance',
#          'Montréal QC H2J 2J9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c06cf964a520eaf920e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adb3067f964a520c82421e3',
#        'name': 'Café Olimpico',
#        'location': {'address': '124 rue Saint-Viateur Ouest',
#         'crossStreet': 'coin Waverly',
#         'lat': 45.52411623375088,
#         'lng': -73.60044245270633,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52411623375088,
#           'lng': -73.60044245270633}],
#         'distance': 3092,
#         'postalCode': 'H2T 2L1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['124 rue Saint-Viateur Ouest (coin Waverly)',
#          'Montréal QC H2T 2L1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '52176519'}},
#       'referralId': 'e-0-4adb3067f964a520c82421e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9aceeef964a520c2d735e3',
#        'name': 'Ta pies',
#        'location': {'address': '4520, avenue du Parc',
#         'crossStreet': 'coin Mont Royal',
#         'lat': 45.51701712983543,
#         'lng': -73.58987652149726,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51701712983543,
#           'lng': -73.58987652149726}],
#         'distance': 2722,
#         'postalCode': 'H2V 4E3',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['4520, avenue du Parc (coin Mont Royal)',
#          'Montréal QC H2V 4E3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '141952177'}},
#       'referralId': 'e-0-4b9aceeef964a520c2d735e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06ff964a52029fb20e3',
#        'name': 'Marché Atwater',
#        'location': {'address': '138 ave. Atwater',
#         'crossStreet': 'coin Rufus Rockhead',
#         'lat': 45.47978972319473,
#         'lng': -73.57677539375054,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.47978972319473,
#           'lng': -73.57677539375054}],
#         'distance': 3261,
#         'postalCode': 'H4C 2G3',
#         'cc': 'CA',
#         'neighborhood': 'Le Sud-Ouest, Montreal, QC',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['138 ave. Atwater (coin Rufus Rockhead)',
#          'Montréal QC H4C 2G3',
#          'Canada']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c06ff964a52029fb20e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0f0945f964a5206a5e23e3',
#        'name': 'Ferreira Café',
#        'location': {'address': '1446 rue Peel',
#         'crossStreet': 'entre St-Catherine & De Maisonneuve',
#         'lat': 45.500434,
#         'lng': -73.57406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.500434,
#           'lng': -73.57406}],
#         'distance': 2855,
#         'postalCode': 'H3A 1S8',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1446 rue Peel (entre St-Catherine & De Maisonneuve)',
#          'Montréal QC H3A 1S8',
#          'Canada']},
#        'categories': [{'id': '4def73e84765ae376e57713a',
#          'name': 'Portuguese Restaurant',
#          'pluralName': 'Portuguese Restaurants',
#          'shortName': 'Portuguese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0f0945f964a5206a5e23e3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c06af964a520e8f820e3',
#        'name': 'Sofitel Montréal Le Carré Doré',
#        'location': {'address': '1155 rue Sherbrooke O',
#         'crossStreet': 'Between Peel and Stanley',
#         'lat': 45.50149907053877,
#         'lng': -73.57752643526283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50149907053877,
#           'lng': -73.57752643526283}],
#         'distance': 2606,
#         'postalCode': 'H3A 2N3',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1155 rue Sherbrooke O (Between Peel and Stanley)',
#          'Montréal QC H3A 2N3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
# ...
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b369b9cf964a520093925e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b155087f964a520bab023e3',
#        'name': 'Centre Bell',
#        'location': {'address': '1909 Ave. des Canadiens-de-Montréal',
#         'crossStreet': 'Rue de la Montagne',
#         'lat': 45.49636670169006,
#         'lng': -73.56984173474704,
#         'distance': 3163,
#         'postalCode': 'H4B 5E8',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['1909 Ave. des Canadiens-de-Montréal (Rue de la Montagne)',
#          'Montréal QC H4B 5E8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d185941735',
#          'name': 'Hockey Arena',
#          'pluralName': 'Hockey Arenas',
#          'shortName': 'Hockey',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_hockey_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36637458'}},
#       'referralId': 'e-0-4b155087f964a520bab023e3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1c1b50f964a5203e0224e3',
#        'name': 'Empire',
#        'location': {'address': '2020 Robert-Bourassa',
#         'lat': 45.5039520190659,
#         'lng': -73.571839928627,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.5039520190659,
#           'lng': -73.571839928627}],
#         'distance': 3097,
#         'postalCode': 'H3A 2A5',
#         'cc': 'CA',
#         'neighborhood': 'Ville-Marie',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['2020 Robert-Bourassa',
#          'Montréal QC H3A 2A5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1c1b50f964a5203e0224e3-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a3a8b911d2f28443f3384b',
#        'name': 'Salon de thé Cardinal / Cardinal Tea Room',
#        'location': {'address': '5326, boulevard Saint-Laurent',
#         'lat': 45.52472116381693,
#         'lng': -73.5964637069834,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52472116381693,
#           'lng': -73.5964637069834}],
#         'distance': 3248,
#         'postalCode': 'H2T 1A5',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['5326, boulevard Saint-Laurent',
#          'Montréal QC H2T 1A5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52a3a8b911d2f28443f3384b-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57cdba55498ef7ba864578f4',
#        'name': 'Café Nocturne',
#        'location': {'address': '19, rue Prince-Arthur Ouest',
#         'crossStreet': 'entre St-Laurent & Clark',
#         'lat': 45.51356573872014,
#         'lng': -73.57284903674521,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51356573872014,
#           'lng': -73.57284903674521}],
#         'distance': 3446,
#         'postalCode': 'H2X 1S4',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['19, rue Prince-Arthur Ouest (entre St-Laurent & Clark)',
#          'Montréal QC H2X 1S4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57cdba55498ef7ba864578f4-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56e9cf37498e8d07ac01d8f4',
#        'name': 'Crew Collective & Cafe',
#        'location': {'address': '360 Saint Jacques',
#         'lat': 45.50239947219616,
#         'lng': -73.55920178694564,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.50239947219616,
#           'lng': -73.55920178694564}],
#         'distance': 4033,
#         'postalCode': 'H2Y 2N1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['360 Saint Jacques',
#          'Montréal QC H2Y 2N1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '185140064'}},
#       'referralId': 'e-0-56e9cf37498e8d07ac01d8f4-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55634921498e57b144d55b38',
#        'name': 'Loïc',
#        'location': {'address': '5001, rue Notre-Dame Ouest',
#         'crossStreet': 'coin St-Rémi',
#         'lat': 45.47050677352771,
#         'lng': -73.59099955461367,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.47050677352771,
#           'lng': -73.59099955461367}],
#         'distance': 3335,
#         'postalCode': 'H4C 1T2',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['5001, rue Notre-Dame Ouest (coin St-Rémi)',
#          'Montréal QC H4C 1T2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55634921498e57b144d55b38-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de0f002c65bcc724f4b48e7',
#        'name': 'Satay Brothers',
#        'location': {'address': 'Marché Atwater',
#         'lat': 45.4800609565644,
#         'lng': -73.57739361095257,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.4800609565644,
#           'lng': -73.57739361095257}],
#         'distance': 3204,
#         'postalCode': 'H4C 1Y9',
#         'cc': 'CA',
#         'neighborhood': 'Le Sud-Ouest',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['Marché Atwater',
#          'Montréal QC H4C 1Y9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de0f002c65bcc724f4b48e7-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad8c39cf964a520761421e3',
#        'name': 'Café Névé',
#        'location': {'address': '151 rue Rachel Est',
#         'crossStreet': 'coin De Bullion',
#         'lat': 45.519445745752925,
#         'lng': -73.58046285424952,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.519445745752925,
#           'lng': -73.58046285424952}],
#         'distance': 3400,
#         'postalCode': 'H2W 1E1',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['151 rue Rachel Est (coin De Bullion)',
#          'Montréal QC H2W 1E1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad8c39cf964a520761421e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cde096edb125481535f2ece',
#        'name': "Cat's Corner",
#        'location': {'address': '3451 St-Laurent 3rd Floor',
#         'crossStreet': 'Sherbrooke',
#         'lat': 45.51289345220704,
#         'lng': -73.5704025392902,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.51289345220704,
#           'lng': -73.5704025392902}],
#         'distance': 3572,
#         'postalCode': 'H2X 2T6',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['3451 St-Laurent 3rd Floor (Sherbrooke)',
#          'Montréal QC H2X 2T6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d134941735',
#          'name': 'Dance Studio',
#          'pluralName': 'Dance Studios',
#          'shortName': 'Dance Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '71192704'}},
#       'referralId': 'e-0-4cde096edb125481535f2ece-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be6efedbcef2d7fc89e05e5',
#        'name': "Les Co'Pains d'Abord",
#        'location': {'address': '418 rue Rachel Est',
#         'crossStreet': 'St-Denis',
#         'lat': 45.522078,
#         'lng': -73.577743,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.522078,
#           'lng': -73.577743}],
#         'distance': 3759,
#         'postalCode': 'H2J 2G7',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['418 rue Rachel Est (St-Denis)',
#          'Montréal QC H2J 2G7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '197735997'}},
#       'referralId': 'e-0-4be6efedbcef2d7fc89e05e5-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bae7d88f964a520cfb83be3',
#        'name': 'Afroditi Bakery',
#        'location': {'address': '756 rue St-Roch',
#         'lat': 45.52844541583584,
#         'lng': -73.63001448945782,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52844541583584,
#           'lng': -73.63001448945782}],
#         'distance': 3799,
#         'postalCode': 'H3N 1L3',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['756 rue St-Roch',
#          'Montréal QC H3N 1L3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bae7d88f964a520cfb83be3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b59f335f964a5202aa328e3',
#        'name': 'naada yoga',
#        'location': {'address': '5540 rue Casgrain',
#         'crossStreet': 'St-Viateur',
#         'lat': 45.52686437190895,
#         'lng': -73.59747857018634,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.52686437190895,
#           'lng': -73.59747857018634}],
#         'distance': 3450,
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['5540 rue Casgrain (St-Viateur)',
#          'Montréal QC',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b59f335f964a5202aa328e3-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57939795498e766234b1e9e7',
#        'name': 'Myriade Espresso Bar',
#        'location': {'address': '4627 Saint-Denis Street',
#         'lat': 45.524803745040394,
#         'lng': -73.58458773616813,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 45.524803745040394,
#           'lng': -73.58458773616813}],
#         'distance': 3670,
#         'postalCode': 'H2J 2L4',
#         'cc': 'CA',
#         'city': 'Montréal',
#         'state': 'QC',
#         'country': 'Canada',
#         'formattedAddress': ['4627 Saint-Denis Street',
#          'Montréal QC H2J 2L4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57939795498e766234b1e9e7-99'}]}]}}

# %% [markdown]
# The following **get_category_type** function is borrowed from a previous lab and will be used to extract the pertinent information from each venue.

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# #### Next we clean up the json file using *Pandas*.

# %%
venues = results['response']['groups'][0]['items']
    
mtl_venues = json_normalize(venues)

filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
mtl_venues = mtl_venues.loc[:, filtered_columns]

mtl_venues['venue.categories'] = mtl_venues.apply(get_category_type, axis=1)

mtl_venues.columns = [col.split(".")[-1] for col in mtl_venues.columns]

mtl_venues.head()
# Out:
#                                       name     categories        lat  \
# 0                       Parc du Mont-Royal           Park  45.504079
# 1                                   CEPSUM    College Gym  45.508320
# 2                      Parc Westmount Park           Park  45.481574
# 3                     Chalet du Mont-Royal  Historic Site  45.503636
# 4  Musée des beaux-arts de Montréal (MBAM)     Art Museum  45.498436
#
#          lng
# 0 -73.587321
# 1 -73.612664
# 2 -73.597476
# 3 -73.587095
# 4 -73.579715

# %%
mtl_venues.shape
# Out:
# (100, 4)

# %%
mtl_venues.to_excel("mtl_trending_venues.xlsx")

# %% [markdown]
# As we can see, despite the fact that I set a limit of 500 venues within a 20 km radius, Foursquare returned only 100 venues because that is the maximum supported amount of return values.

# %% [markdown]
# Now that we have all the data we need and it is cleaned up, let's start exploring it visually.

# %% [markdown]
# ## III. Exploratory Data Analysis

# %% [markdown]
# #### Create a map using Folium to visualize the locations of the Bixi docking stations (in blue) and the trending venues (in red).

# %% [markdown]
# Let's first define latitudes and longitude values for both stations and trending venues, for simplicity.

# %%
station_name = stations_df['name']
station_lat = stations_df['latitude']
station_lng = stations_df['longitude']
venue_name = mtl_venues['name']
venue_lat = mtl_venues['lat']
venue_lng = mtl_venues['lng']

# %%
# create map of Montreal using latitude and longitude values
mtl_map = folium.Map(location=[mtl_latitude, mtl_longitude], zoom_start=11)

# add markers to map to visualize the Bixi docking stations
for lat, lng, label in zip(station_lat, station_lng, station_name):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(mtl_map)

# add markers to map to visualize the trending venues in Montreal
for lat, lng, label in zip(venue_lat, venue_lng, venue_name):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(mtl_map)  

mtl_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Based on the map, it is clear that that are a lot more bixi docking stations (615) than trending venues (100), and the trending venues are concentrated in Montreal's downtown core.

# %% [markdown]
# Therefore, it would be relevant to filter the docking stations and analyze the ones that are within 100 meters of a trending venue.

# %% [markdown]
# In order to do this, we will first check the data types for each dataframe, to ensure they are in the correct format. Then we will process to create a series of functions and iterations to determine the distance between each venue and docking station, return only the venues and stations within 100 meter radius, and store all this information into a new dataframe.

# %% [markdown]
# #### Let's check the data types.

# %%
mtl_venues.dtypes
# Out:
# name           object
# categories     object
# lat           float64
# lng           float64
# dtype: object

# %%
stations_df.dtypes
# Out:
# Code           int64
# name          object
# latitude     float64
# longitude    float64
# dtype: object

# %% [markdown]
# Everything looks good.

# %% [markdown]
# #### Now let's create a function that will calculate the distance between two locations. It uses the Haversine formula.

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    
    # necessary to convert coordinates to radians in order to use trig functions
    x1, y1, x2, y2 = map(radians, [lon1, lat1, lon2, lat2]) 

    # haversine formula 
    dlon = x2 - x1 
    dlat = y2 - y1 
    a = sin(dlat/2)**2 + cos(y1) * cos(y2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371000 # Radius of earth in meters
    distance = c * r
    
    # will return distance in meters
    return(distance)

# %% [markdown]
# #### In this next step, we will iterate for all the venues and docking stations in order to calculate the distance between each one, return only values within a distance of 100 meters, and stores all this information into a new dataframe we will call *locations_df*.

# %%
venue_name = []
venue_lat = []
venue_lng = []
venue_cat = []
station_name = []
station_lat = []
station_lng = []
distance = []
i = 0
j = 0
for i in range(0, len(mtl_venues['name'])): # iterates all rows in the mtl_venues dataframe
    
    name1 = mtl_venues.iat[i,0] 
    lat1 = mtl_venues.iat[i,2]
    lng1 = mtl_venues.iat[i,3] 
    cat1 = mtl_venues.iat[i,1]
    
    for j in range(0, len(stations_df['name'])): # iterates all rows in the stations_df dataframe
        
        name2 = stations_df.iat[j,1]
        lat2 = stations_df.iat[j,2]
        lng2 = stations_df.iat[j,3]
        d = haversine(lng1, lat1, lng2, lat2)
        
        if (d <= 100): # append values only if distance is within 100 meters
            venue_name.append(name1),
            venue_lat.append(lat1),
            venue_lng.append(lng1),
            venue_cat.append(cat1),
            station_name.append(name2),
            station_lat.append(lat2),
            station_lng.append(lng2),
            distance.append(d)
        
        i = i+1
    
    j = j+1

df_locations = pd.DataFrame({'Venue': venue_name, 
                             'Venue Latitude': venue_lat, 
                             'Venue Longitude': venue_lng, 
                             'Venue Category': venue_cat,
                             'Docking Station': station_name, 
                             'Docking Station Latitude': station_lat, 
                             'Docking Station Longitude': station_lng,
                             'Distance (m)': distance})

df_locations.head()
# Out:
#                        Venue  Venue Latitude  Venue Longitude  \
# 0            Moksha Yoga NDG       45.476606       -73.621498
# 1              Maison Boulud       45.500062       -73.578324
# 2  The Ritz-Carlton Montréal       45.500191       -73.578127
# 3              Tiffany & Co.       45.499782       -73.578403
# 4                      Damas       45.522596       -73.613112
#
#              Venue Category              Docking Station  \
# 0               Yoga Studio       de Monkland / Girouard
# 1         French Restaurant  de la Montagne / Sherbrooke
# 2                     Hotel  de la Montagne / Sherbrooke
# 3             Jewelry Store  de la Montagne / Sherbrooke
# 4  Mediterranean Restaurant       Bloomfield / Van Horne
#
#    Docking Station Latitude  Docking Station Longitude  Distance (m)
# 0                 45.477107                 -73.621438     55.899685
# 1                 45.499745                 -73.579034     65.604786
# 2                 45.499745                 -73.579034     86.358319
# 3                 45.499745                 -73.579034     49.303327
# 4                 45.522586                 -73.612658     35.437825

# %%
df_locations.shape
# Out:
# (65, 8)

# %% [markdown]
# As we can see, there are 65 venues that are within 100 meters of a docking station. This information also tells us that there are 35 venues that are not within 100 meters of a docking station. Let's further explore this information.

# %% [markdown]
# #### Let's filter the dataframe so we have only unique venues.

# %%
df_locations.groupby('Docking Station').count()
# Out:
#                                                 Venue  Venue Latitude  \
# Docking Station
# Atwater / Greene                                    2               2
# Bernard / Jeanne-Mance                              1               1
# Berri / Rachel                                      1               1
# Bloomfield / Van Horne                              1               1
# Clark / Prince-Arthur                               1               1
# Clark / Rachel                                      1               1
# Crescent / Ste-Catherine                            1               1
# Crescent / de Maisonneuve                           1               1
# Cypress / Peel                                      1               1
# Duluth / St-Laurent                                 1               1
# Duluth / de l'Esplanade                             1               1
# Duvernay / Charlevoix                               2               2
# Hutchison / Sherbrooke                              2               2
# Jeanne-Mance / St-Viateur                           1               1
# Laval / du Mont-Royal                               1               1
# Maguire / St-Laurent                                3               3
# Mansfield / René-Lévesque                           1               1
# Marché Atwater                                      3               3
# Metcalfe / du Square-Dorchester                     1               1
# Milton / Clark                                      1               1
# Mozart / St-Laurent                                 1               1
# Métro Peel (de Maisonneuve / Stanley)               3               3
# Métro St-Laurent (de Maisonneuve / St-Laurent)      2               2
# Napoléon / St-Dominique                             2               2
# Palm / St-Remi                                      1               1
# Querbes / Laurier                                   1               1
# Rivard / Rachel                                     1               1
# Roy / St-Laurent                                    1               1
# Square Phillips                                     1               1
# St-Dominique / St-Viateur                           1               1
# St-Jacques / St-Pierre                              1               1
# Stanley / Sherbrooke                                1               1
# Stanley / Ste-Catherine                             1               1
# Ste-Catherine / St-Laurent                          1               1
# Ste-Catherine / St-Marc                             1               1
# Union / Cathcart                                    1               1
# Vallières / St-Laurent                              2               2
# Villeneuve / St-Laurent                             2               2
# Waverly / St-Viateur                                1               1
# de Gaspé / St-Viateur                               1               1
# de Maisonneuve / City Councillors                   1               1
# de Maisonneuve / Peel                               3               3
# de Monkland / Girouard                              1               1
# de l'Esplanade / du Mont-Royal                      1               1
# de la Cathédrale / René-Lévesque                    1               1
# de la Montagne / Sherbrooke                         3               3
# du Mont-Royal / du Parc                             1               1
# du President-Kennedy / Robert-Bourassa              1               1
#
#                                                 Venue Longitude  \
# Docking Station
# Atwater / Greene                                              2
# Bernard / Jeanne-Mance                                        1
# Berri / Rachel                                                1
# Bloomfield / Van Horne                                        1
# Clark / Prince-Arthur                                         1
# Clark / Rachel                                                1
# Crescent / Ste-Catherine                                      1
# Crescent / de Maisonneuve                                     1
# Cypress / Peel                                                1
# Duluth / St-Laurent                                           1
# Duluth / de l'Esplanade                                       1
# Duvernay / Charlevoix                                         2
# Hutchison / Sherbrooke                                        2
# Jeanne-Mance / St-Viateur                                     1
# Laval / du Mont-Royal                                         1
# Maguire / St-Laurent                                          3
# Mansfield / René-Lévesque                                     1
# Marché Atwater                                                3
# Metcalfe / du Square-Dorchester                               1
# Milton / Clark                                                1
# Mozart / St-Laurent                                           1
# Métro Peel (de Maisonneuve / Stanley)                         3
# Métro St-Laurent (de Maisonneuve / St-Laurent)                2
# Napoléon / St-Dominique                                       2
# Palm / St-Remi                                                1
# Querbes / Laurier                                             1
# Rivard / Rachel                                               1
# Roy / St-Laurent                                              1
# Square Phillips                                               1
# St-Dominique / St-Viateur                                     1
# St-Jacques / St-Pierre                                        1
# Stanley / Sherbrooke                                          1
# Stanley / Ste-Catherine                                       1
# Ste-Catherine / St-Laurent                                    1
# Ste-Catherine / St-Marc                                       1
# Union / Cathcart                                              1
# Vallières / St-Laurent                                        2
# Villeneuve / St-Laurent                                       2
# Waverly / St-Viateur                                          1
# de Gaspé / St-Viateur                                         1
# de Maisonneuve / City Councillors                             1
# de Maisonneuve / Peel                                         3
# de Monkland / Girouard                                        1
# de l'Esplanade / du Mont-Royal                                1
# de la Cathédrale / René-Lévesque                              1
# de la Montagne / Sherbrooke                                   3
# du Mont-Royal / du Parc                                       1
# du President-Kennedy / Robert-Bourassa                        1
#
#                                                 Venue Category  \
# Docking Station
# Atwater / Greene                                             2
# Bernard / Jeanne-Mance                                       1
# Berri / Rachel                                               1
# Bloomfield / Van Horne                                       1
# Clark / Prince-Arthur                                        1
# Clark / Rachel                                               1
# Crescent / Ste-Catherine                                     1
# Crescent / de Maisonneuve                                    1
# Cypress / Peel                                               1
# Duluth / St-Laurent                                          1
# Duluth / de l'Esplanade                                      1
# Duvernay / Charlevoix                                        2
# Hutchison / Sherbrooke                                       2
# Jeanne-Mance / St-Viateur                                    1
# Laval / du Mont-Royal                                        1
# Maguire / St-Laurent                                         3
# Mansfield / René-Lévesque                                    1
# Marché Atwater                                               3
# Metcalfe / du Square-Dorchester                              1
# Milton / Clark                                               1
# Mozart / St-Laurent                                          1
# Métro Peel (de Maisonneuve / Stanley)                        3
# Métro St-Laurent (de Maisonneuve / St-Laurent)               2
# Napoléon / St-Dominique                                      2
# Palm / St-Remi                                               1
# Querbes / Laurier                                            1
# Rivard / Rachel                                              1
# Roy / St-Laurent                                             1
# Square Phillips                                              1
# St-Dominique / St-Viateur                                    1
# St-Jacques / St-Pierre                                       1
# Stanley / Sherbrooke                                         1
# Stanley / Ste-Catherine                                      1
# Ste-Catherine / St-Laurent                                   1
# Ste-Catherine / St-Marc                                      1
# Union / Cathcart                                             1
# Vallières / St-Laurent                                       2
# Villeneuve / St-Laurent                                      2
# Waverly / St-Viateur                                         1
# de Gaspé / St-Viateur                                        1
# de Maisonneuve / City Councillors                            1
# de Maisonneuve / Peel                                        3
# de Monkland / Girouard                                       1
# de l'Esplanade / du Mont-Royal                               1
# de la Cathédrale / René-Lévesque                             1
# de la Montagne / Sherbrooke                                  3
# du Mont-Royal / du Parc                                      1
# du President-Kennedy / Robert-Bourassa                       1
#
#                                                 Docking Station Latitude  \
# Docking Station
# Atwater / Greene                                                       2
# Bernard / Jeanne-Mance                                                 1
# Berri / Rachel                                                         1
# Bloomfield / Van Horne                                                 1
# Clark / Prince-Arthur                                                  1
# Clark / Rachel                                                         1
# Crescent / Ste-Catherine                                               1
# Crescent / de Maisonneuve                                              1
# Cypress / Peel                                                         1
# Duluth / St-Laurent                                                    1
# Duluth / de l'Esplanade                                                1
# Duvernay / Charlevoix                                                  2
# Hutchison / Sherbrooke                                                 2
# Jeanne-Mance / St-Viateur                                              1
# Laval / du Mont-Royal                                                  1
# Maguire / St-Laurent                                                   3
# Mansfield / René-Lévesque                                              1
# Marché Atwater                                                         3
# Metcalfe / du Square-Dorchester                                        1
# Milton / Clark                                                         1
# Mozart / St-Laurent                                                    1
# Métro Peel (de Maisonneuve / Stanley)                                  3
# Métro St-Laurent (de Maisonneuve / St-Laurent)                         2
# Napoléon / St-Dominique                                                2
# Palm / St-Remi                                                         1
# Querbes / Laurier                                                      1
# Rivard / Rachel                                                        1
# Roy / St-Laurent                                                       1
# Square Phillips                                                        1
# St-Dominique / St-Viateur                                              1
# St-Jacques / St-Pierre                                                 1
# Stanley / Sherbrooke                                                   1
# Stanley / Ste-Catherine                                                1
# Ste-Catherine / St-Laurent                                             1
# Ste-Catherine / St-Marc                                                1
# Union / Cathcart                                                       1
# Vallières / St-Laurent                                                 2
# Villeneuve / St-Laurent                                                2
# Waverly / St-Viateur                                                   1
# de Gaspé / St-Viateur                                                  1
# de Maisonneuve / City Councillors                                      1
# de Maisonneuve / Peel                                                  3
# de Monkland / Girouard                                                 1
# de l'Esplanade / du Mont-Royal                                         1
# de la Cathédrale / René-Lévesque                                       1
# de la Montagne / Sherbrooke                                            3
# du Mont-Royal / du Parc                                                1
# du President-Kennedy / Robert-Bourassa                                 1
#
#                                                 Docking Station Longitude  \
# Docking Station
# Atwater / Greene                                                        2
# Bernard / Jeanne-Mance                                                  1
# Berri / Rachel                                                          1
# Bloomfield / Van Horne                                                  1
# Clark / Prince-Arthur                                                   1
# Clark / Rachel                                                          1
# Crescent / Ste-Catherine                                                1
# Crescent / de Maisonneuve                                               1
# Cypress / Peel                                                          1
# Duluth / St-Laurent                                                     1
# Duluth / de l'Esplanade                                                 1
# Duvernay / Charlevoix                                                   2
# Hutchison / Sherbrooke                                                  2
# Jeanne-Mance / St-Viateur                                               1
# Laval / du Mont-Royal                                                   1
# Maguire / St-Laurent                                                    3
# Mansfield / René-Lévesque                                               1
# Marché Atwater                                                          3
# Metcalfe / du Square-Dorchester                                         1
# Milton / Clark                                                          1
# Mozart / St-Laurent                                                     1
# Métro Peel (de Maisonneuve / Stanley)                                   3
# Métro St-Laurent (de Maisonneuve / St-Laurent)                          2
# Napoléon / St-Dominique                                                 2
# Palm / St-Remi                                                          1
# Querbes / Laurier                                                       1
# Rivard / Rachel                                                         1
# Roy / St-Laurent                                                        1
# Square Phillips                                                         1
# St-Dominique / St-Viateur                                               1
# St-Jacques / St-Pierre                                                  1
# Stanley / Sherbrooke                                                    1
# Stanley / Ste-Catherine                                                 1
# Ste-Catherine / St-Laurent                                              1
# Ste-Catherine / St-Marc                                                 1
# Union / Cathcart                                                        1
# Vallières / St-Laurent                                                  2
# Villeneuve / St-Laurent                                                 2
# Waverly / St-Viateur                                                    1
# de Gaspé / St-Viateur                                                   1
# de Maisonneuve / City Councillors                                       1
# de Maisonneuve / Peel                                                   3
# de Monkland / Girouard                                                  1
# de l'Esplanade / du Mont-Royal                                          1
# de la Cathédrale / René-Lévesque                                        1
# de la Montagne / Sherbrooke                                             3
# du Mont-Royal / du Parc                                                 1
# du President-Kennedy / Robert-Bourassa                                  1
#
#                                                 Distance (m)
# Docking Station
# Atwater / Greene                                           2
# Bernard / Jeanne-Mance                                     1
# Berri / Rachel                                             1
# Bloomfield / Van Horne                                     1
# Clark / Prince-Arthur                                      1
# Clark / Rachel                                             1
# Crescent / Ste-Catherine                                   1
# Crescent / de Maisonneuve                                  1
# Cypress / Peel                                             1
# Duluth / St-Laurent                                        1
# Duluth / de l'Esplanade                                    1
# Duvernay / Charlevoix                                      2
# Hutchison / Sherbrooke                                     2
# Jeanne-Mance / St-Viateur                                  1
# Laval / du Mont-Royal                                      1
# Maguire / St-Laurent                                       3
# Mansfield / René-Lévesque                                  1
# Marché Atwater                                             3
# Metcalfe / du Square-Dorchester                            1
# Milton / Clark                                             1
# Mozart / St-Laurent                                        1
# Métro Peel (de Maisonneuve / Stanley)                      3
# Métro St-Laurent (de Maisonneuve / St-Laurent)             2
# Napoléon / St-Dominique                                    2
# Palm / St-Remi                                             1
# Querbes / Laurier                                          1
# Rivard / Rachel                                            1
# Roy / St-Laurent                                           1
# Square Phillips                                            1
# St-Dominique / St-Viateur                                  1
# St-Jacques / St-Pierre                                     1
# Stanley / Sherbrooke                                       1
# Stanley / Ste-Catherine                                    1
# Ste-Catherine / St-Laurent                                 1
# Ste-Catherine / St-Marc                                    1
# Union / Cathcart                                           1
# Vallières / St-Laurent                                     2
# Villeneuve / St-Laurent                                    2
# Waverly / St-Viateur                                       1
# de Gaspé / St-Viateur                                      1
# de Maisonneuve / City Councillors                          1
# de Maisonneuve / Peel                                      3
# de Monkland / Girouard                                     1
# de l'Esplanade / du Mont-Royal                             1
# de la Cathédrale / René-Lévesque                           1
# de la Montagne / Sherbrooke                                3
# du Mont-Royal / du Parc                                    1
# du President-Kennedy / Robert-Bourassa                     1

# %%
print('There are {} unique categories.'.format(len(df_locations['Venue Category'].unique())))
# Out:
# There are 37 unique categories.

# %%
print('There are {} unique venues.'.format(len(df_locations['Venue'].unique())))
# Out:
# There are 55 unique venues.

# %%
print('There are {} unique docking station locations.'.format(len(df_locations['Docking Station'].unique())))
# Out:
# There are 48 unique docking station locations.

# %%
# sort the dataframe by distance in ascending value, save to new dataframe
sorted_locations = df_locations.sort_values(by='Distance (m)', ascending=True)
sorted_locations.head()
# Out:
#                    Venue  Venue Latitude  Venue Longitude  \
# 42       Pizzeria Magpie       45.524711       -73.595744
# 28          Espace Nomad       45.521402       -73.589277
# 5                   Kazu       45.493014       -73.580203
# 58        Satay Brothers       45.480061       -73.577394
# 61  Les Co'Pains d'Abord       45.522078       -73.577743
#
#          Venue Category          Docking Station  Docking Station Latitude  \
# 42          Pizza Place     Maguire / St-Laurent                 45.524628
# 28                  Spa  Villeneuve / St-Laurent                 45.521342
# 5   Japanese Restaurant  Ste-Catherine / St-Marc                 45.492897
# 58     Asian Restaurant           Marché Atwater                 45.480208
# 61               Bakery          Rivard / Rachel                 45.522278
#
#     Docking Station Longitude  Distance (m)
# 42                 -73.595811     10.583038
# 28                 -73.589419     12.969461
# 5                  -73.580294     14.775945
# 58                 -73.577599     22.883836
# 61                 -73.577591     25.170705

# %% [markdown]
# Now we'll filter the dataframe in order to only keep the unique venues. Out of the duplicates, only the one with the smallest distance will be kept. To do this, we'll first sort the dataframe by distance in ascending order, then drop the duplicates and only keep the first (which will have the smallest distance).

# %%
# filter the dataframe to remove duplicate venues, and keep only first of duplicates, save to new dataframe
filtered_locations = sorted_locations.drop_duplicates(subset='Venue', keep='first')
filtered_locations
# Out:
#                                         Venue  Venue Latitude  \
# 42                            Pizzeria Magpie       45.524711
# 28                               Espace Nomad       45.521402
# 5                                        Kazu       45.493014
# 58                             Satay Brothers       45.480061
# 61                       Les Co'Pains d'Abord       45.522078
# 6                                     Mandy's       45.498286
# 55                              Café Nocturne       45.513566
# 50                                Il Focolaio       45.504009
# 12                           Club Sportif MAA       45.500700
# 15                                    Darling       45.518995
# 4                                       Damas       45.522596
# 8                                   Enso Yoga       45.500743
# 18                              Café Olimpico       45.524116
# 38                             Trip de Bouffe       45.522708
# 39                    Omnivore Comptoir Grill       45.519061
# 56                     Crew Collective & Cafe       45.502399
# 17                     Dominion Square Tavern       45.500405
# 60                               Cat's Corner       45.512893
# 29                                   Le Filet       45.517834
# 34            Cathédrale Marie-Reine-du-Monde       45.499614
# 3                               Tiffany & Co.       45.499782
# 10      St-Viateur Bagel (La Maison du Bagel)       45.522573
# 16                                Frank & Oak       45.499573
# 54  Salon de thé Cardinal / Cardinal Tea Room       45.524721
# 13                                  Noren　のれん       45.517026
# 44                                      Cadet       45.510260
# 0                             Moksha Yoga NDG       45.476606
# 52                           Milano Fruiterie       45.533055
# 23             Sofitel Montréal Le Carré Doré       45.501499
# 9                           Drawn & Quarterly       45.524748
# 30                         Boucherie Lawrence       45.524232
# 1                               Maison Boulud       45.500062
# 24                                Café Parvis       45.505817
# 19                                    Ta pies       45.517017
# 22                              Ferreira Café       45.500434
# 63                                 naada yoga       45.526864
# 36                             Café Santropol       45.515610
# 48                              SAQ Sélection       45.480446
# 37                                 Aux Vivres       45.521086
# 33                                       Jano       45.516066
# 20                             Marché Atwater       45.479790
# 40                              Louis Vuitton       45.497820
# 14                                     Leméac       45.518191
# 53                                     Empire       45.503952
# 47                              Bouillon Bilk       45.510845
# 26                       Moksha Yoga Montreal       45.516057
# 2                   The Ritz-Carlton Montréal       45.500191
# 27                        Papeterie Nota Bene       45.508571
# 31                        Pikolo Espresso Bar       45.508606
# 57                                       Loïc       45.470507
# 41                              Le Majestique       45.517445
# 32                            Le Vin Papillon       45.482763
# 46                          La Vieille Europe       45.515891
# 25                            MELK Bar à Café       45.498480
# 43                            Liverpool House       45.482893
#
#     Venue Longitude                 Venue Category  \
# 42       -73.595744                    Pizza Place
# 28       -73.589277                            Spa
# 5        -73.580203            Japanese Restaurant
# 58       -73.577394               Asian Restaurant
# 61       -73.577743                         Bakery
# 6        -73.577895                    Salad Place
# 55       -73.572849                           Café
# 50       -73.568213                    Pizza Place
# 12       -73.574817                            Gym
# 15       -73.584061                         Lounge
# 4        -73.613112       Mediterranean Restaurant
# 8        -73.574943                    Yoga Studio
# 18       -73.600442                           Café
# 38       -73.584088      Middle Eastern Restaurant
# 39       -73.584116      Middle Eastern Restaurant
# 56       -73.559202                           Café
# 17       -73.571636                      Gastropub
# 60       -73.570403                   Dance Studio
# 29       -73.588419             Seafood Restaurant
# 34       -73.569367                         Church
# 3        -73.578403                  Jewelry Store
# 10       -73.601878                     Bagel Shop
# 16       -73.574328                    Men's Store
# 54       -73.596464                       Tea Room
# 13       -73.582608            Japanese Restaurant
# 44       -73.564584                     Restaurant
# 0        -73.621498                    Yoga Studio
# 52       -73.614722                  Grocery Store
# 23       -73.577526                          Hotel
# 9        -73.604614                      Bookstore
# 30       -73.595292                  Deli / Bodega
# 1        -73.578324              French Restaurant
# 24       -73.569302                           Café
# 19       -73.589877          Australian Restaurant
# 22       -73.574060          Portuguese Restaurant
# 63       -73.597479                    Yoga Studio
# 36       -73.580611                           Café
# 48       -73.576695                   Liquor Store
# 37       -73.588506  Vegetarian / Vegan Restaurant
# 33       -73.577361          Portuguese Restaurant
# 20       -73.576775                         Market
# 40       -73.575306                       Boutique
# 14       -73.597304              French Restaurant
# 53       -73.571840            Sporting Goods Shop
# 47       -73.566017                     Restaurant
# 26       -73.577188                    Yoga Studio
# 2        -73.578127                          Hotel
# 27       -73.571672  Paper / Office Supplies Store
# 31       -73.571772                    Coffee Shop
# 57       -73.591000                         Lounge
# 41       -73.580368                     Restaurant
# 32       -73.575514                       Wine Bar
# 46       -73.576982                   Gourmet Shop
# 25       -73.572076                           Café
# 43       -73.575256                     Restaurant
#
#                                    Docking Station  Docking Station Latitude  \
# 42                            Maguire / St-Laurent                 45.524628
# 28                         Villeneuve / St-Laurent                 45.521342
# 5                          Ste-Catherine / St-Marc                 45.492897
# 58                                  Marché Atwater                 45.480208
# 61                                 Rivard / Rachel                 45.522278
# 6                        Crescent / de Maisonneuve                 45.498112
# 55                           Clark / Prince-Arthur                 45.513303
# 50                                 Square Phillips                 45.503738
# 12                           de Maisonneuve / Peel                 45.500951
# 15                          Vallières / St-Laurent                 45.518967
# 4                           Bloomfield / Van Horne                 45.522586
# 8                            de Maisonneuve / Peel                 45.500951
# 18                            Waverly / St-Viateur                 45.523856
# 38                           Laval / du Mont-Royal                 45.522365
# 39                          Vallières / St-Laurent                 45.518967
# 56                          St-Jacques / St-Pierre                 45.502786
# 17                 Metcalfe / du Square-Dorchester                 45.500208
# 60                                  Milton / Clark                 45.512541
# 29                  de l'Esplanade / du Mont-Royal                 45.518253
# 34                de la Cathédrale / René-Lévesque                 45.499191
# 3                      de la Montagne / Sherbrooke                 45.499745
# 10                       Jeanne-Mance / St-Viateur                 45.523026
# 16                         Stanley / Ste-Catherine                 45.499344
# 54                            Maguire / St-Laurent                 45.524628
# 13                                  Clark / Rachel                 45.517354
# 44  Métro St-Laurent (de Maisonneuve / St-Laurent)                 45.510660
# 0                           de Monkland / Girouard                 45.477107
# 52                             Mozart / St-Laurent                 45.533180
# 23                            Stanley / Sherbrooke                 45.501041
# 9                           Bernard / Jeanne-Mance                 45.524286
# 30                            Maguire / St-Laurent                 45.524628
# 1                      de la Montagne / Sherbrooke                 45.499745
# 24               de Maisonneuve / City Councillors                 45.506190
# 19                         du Mont-Royal / du Parc                 45.517000
# 22                           de Maisonneuve / Peel                 45.500951
# 63                       St-Dominique / St-Viateur                 45.526557
# 36                         Duluth / de l'Esplanade                 45.515092
# 48                                  Marché Atwater                 45.480208
# 37                         Villeneuve / St-Laurent                 45.521342
# 33                         Napoléon / St-Dominique                 45.516745
# 20                                  Marché Atwater                 45.480208
# 40                        Crescent / Ste-Catherine                 45.497092
# 14                               Querbes / Laurier                 45.517540
# 53          du President-Kennedy / Robert-Bourassa                 45.504627
# 47  Métro St-Laurent (de Maisonneuve / St-Laurent)                 45.510660
# 26                         Napoléon / St-Dominique                 45.516745
# 2                      de la Montagne / Sherbrooke                 45.499745
# 27                          Hutchison / Sherbrooke                 45.507810
# 31                          Hutchison / Sherbrooke                 45.507810
# 57                                  Palm / St-Remi                 45.470303
# 41                             Duluth / St-Laurent                 45.516876
# 32                           Duvernay / Charlevoix                 45.482040
# 46                                Roy / St-Laurent                 45.515616
# 25                                  Cypress / Peel                 45.499326
# 43                           Duvernay / Charlevoix                 45.482040
#
#     Docking Station Longitude  Distance (m)
# 42                 -73.595811     10.583038
# 28                 -73.589419     12.969461
# 5                  -73.580294     14.775945
# 58                 -73.577599     22.883836
# 61                 -73.577591     25.170705
# 6                  -73.577615     29.179987
# 55                 -73.572961     30.537609
# 50                 -73.568106     31.290720
# 12                 -73.574578     33.489149
# 15                 -73.583616     34.825866
# 4                  -73.612658     35.437825
# 8                  -73.574578     36.641021
# 18                 -73.600127     37.976787
# 38                 -73.584146     38.484408
# 39                 -73.583616     40.295889
# 56                 -73.559134     43.355469
# 17                 -73.571138     44.564410
# 60                 -73.570677     44.618930
# 29                 -73.588338     47.009552
# 34                 -73.569421     47.213863
# 3                  -73.579034     49.303327
# 10                 -73.601840     50.538247
# 16                 -73.573760     51.069069
# 54                 -73.595811     51.894803
# 13                 -73.582129     52.149124
# 44                 -73.564970     53.678109
# 0                  -73.621438     55.899685
# 52                 -73.615440     57.657500
# 23                 -73.577178     57.728634
# 9                  -73.604973     58.393492
# 30                 -73.595811     59.768675
# 1                  -73.579034     65.604786
# 24                 -73.569954     65.641906
# 19                 -73.589000     68.319860
# 22                 -73.574578     70.226903
# 63                 -73.598276     70.886785
# 36                 -73.581142     70.912305
# 48                 -73.577599     75.253797
# 37                 -73.589419     76.649715
# 33                 -73.577658     78.973763
# 20                 -73.577599     79.278863
# 40                 -73.575549     83.154334
# 14                 -73.597832     83.208770
# 53                 -73.572325     84.019077
# 47                 -73.564970     84.116840
# 26                 -73.577658     84.827436
# 2                  -73.579034     86.358319
# 27                 -73.572080     90.423304
# 31                 -73.572080     91.680589
# 57                 -73.589848     92.611150
# 41                 -73.579460     94.824154
# 32                 -73.574863     95.059025
# 46                 -73.575808     96.447711
# 25                 -73.571768     97.042175
# 43                 -73.574863     99.697293

# %%
len(filtered_locations['Docking Station'].unique())
# Out:
# 41

# %% [markdown]
# We have now a dataframe with 55 unique venues, and the closest docking station to each venue.

# %%
filtered_locations.reset_index(drop=True, inplace=True)
filtered_locations.head()
# Out:
#                   Venue  Venue Latitude  Venue Longitude       Venue Category  \
# 0       Pizzeria Magpie       45.524711       -73.595744          Pizza Place
# 1          Espace Nomad       45.521402       -73.589277                  Spa
# 2                  Kazu       45.493014       -73.580203  Japanese Restaurant
# 3        Satay Brothers       45.480061       -73.577394     Asian Restaurant
# 4  Les Co'Pains d'Abord       45.522078       -73.577743               Bakery
#
#            Docking Station  Docking Station Latitude  \
# 0     Maguire / St-Laurent                 45.524628
# 1  Villeneuve / St-Laurent                 45.521342
# 2  Ste-Catherine / St-Marc                 45.492897
# 3           Marché Atwater                 45.480208
# 4          Rivard / Rachel                 45.522278
#
#    Docking Station Longitude  Distance (m)
# 0                 -73.595811     10.583038
# 1                 -73.589419     12.969461
# 2                 -73.580294     14.775945
# 3                 -73.577599     22.883836
# 4                 -73.577591     25.170705

# %%
filtered_locations.shape
# Out:
# (55, 8)

# %% [markdown]
# After filtering and examining the data, it shows us that we 55 unique venues and 48 unique docking station locations. Some stations will have up to 3 nearby trending venues. Let's see if we can cluster the venues into a *K* number of clusters and determine the closest station to each cluster center. This will be the final result of our analysis.

# %% [markdown]
# Now let's visualize the filtered data.

# %%
# create map of stations and nearby venues using latitude and longitude values
venues_map = folium.Map(location=[mtl_latitude, mtl_longitude], zoom_start=13)

station_name = filtered_locations['Docking Station']
station_lat = filtered_locations['Docking Station Latitude']
station_lng = filtered_locations['Docking Station Longitude']
venue_name = filtered_locations['Venue']
venue_lat = filtered_locations['Venue Latitude']
venue_lng = filtered_locations['Venue Longitude']

# add markers to map to visualize the Bixi docking stations
for lat, lng, label in zip(station_lat, station_lng, station_name):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(venues_map)

# add markers to map to visualize the trending venues in Montreal
for lat, lng, label in zip(venue_lat, venue_lng, venue_name):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(venues_map)  

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# First, I will use **k-means** clustering with HDBSCAN for this task in order to determine the cluster of venues by location. What’s great about HDBSCAN is that it takes into account the distance between geo-locations, as the earth isn't flat. It considers the Haversine function we used previously to determine the distance between venues and docking station locations. Also, I won’t need to specify a K number of clusters, it will return the best number of clusters according to a minimum number of items in a cluster, that I will specify as 3.

# %% [markdown]
# ### Using *k-means* for clustering stations

# %% [markdown]
# What is important to note is that using HDBSCAN does not return cluster centers for each cluster. It returns only segmented clusters, which I will visualize using Folium map and then visually determine the most representative station location (based on location to each venue in the cluster, and the number of closest venues). This essentially will be the final result we are looking for: the location of docking stations that maximize the amount of trending venue nearby.

# %%
from sklearn.cluster import KMeans
# !conda install -c conda-forge hdbscan --yes
# !pip install hdbscan
import hdbscan
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - hdbscan
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     hdbscan-0.8.22             |   py36hd352d35_1         636 KB  conda-forge
#     joblib-0.13.2              |             py_0         180 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         816 KB
#
# The following NEW packages will be INSTALLED:
#
#     hdbscan: 0.8.22-py36hd352d35_1 conda-forge
#     joblib:  0.13.2-py_0           conda-forge
#
#
# Downloading and Extracting Packages
# hdbscan-0.8.22       | 636 KB    | ##################################### | 100%
# joblib-0.13.2        | 180 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Requirement already satisfied: hdbscan in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.8.22)
# Requirement already satisfied: cython>=0.27 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from hdbscan) (0.29.5)
# Collecting numpy>=1.16.0 (from hdbscan)
#   Downloading https://files.pythonhosted.org/packages/87/2d/e4656149cbadd3a8a0369fcd1a9c7d61cc7b87b3903b85389c70c989a696/numpy-1.16.4-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 771kB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from hdbscan) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from hdbscan) (0.20.3)
# Requirement already satisfied: joblib in /opt/conda/envs/Python36/lib/python3.6/site-packages (from hdbscan) (0.13.2)
# ERROR: tensorflow 1.13.1 requires tensorboard<1.14.0,>=1.13.0, which is not installed.
# Installing collected packages: numpy
#   Found existing installation: numpy 1.15.4
#     Uninstalling numpy-1.15.4:
#       Successfully uninstalled numpy-1.15.4
# Successfully installed numpy-1.16.4

# %%
# define number of clusters and X as dataset to be clustered

X = filtered_locations[['Venue Latitude','Venue Longitude']].values

# Using fit_predict to cluster the dataset
rads = np.radians(X)
kmeans = hdbscan.HDBSCAN(min_cluster_size=3, metric='haversine')
cluster_label = kmeans.fit_predict(rads)

# %%
clustered = pd.concat([filtered_locations.reset_index(), pd.DataFrame({'Cluster': cluster_label})], axis=1)
clustered.drop('index', axis=1, inplace=True)
clustered
# Out:
#                                         Venue  Venue Latitude  \
# 0                             Pizzeria Magpie       45.524711
# 1                                Espace Nomad       45.521402
# 2                                        Kazu       45.493014
# 3                              Satay Brothers       45.480061
# 4                        Les Co'Pains d'Abord       45.522078
# 5                                     Mandy's       45.498286
# 6                               Café Nocturne       45.513566
# 7                                 Il Focolaio       45.504009
# 8                            Club Sportif MAA       45.500700
# 9                                     Darling       45.518995
# 10                                      Damas       45.522596
# 11                                  Enso Yoga       45.500743
# 12                              Café Olimpico       45.524116
# 13                             Trip de Bouffe       45.522708
# 14                    Omnivore Comptoir Grill       45.519061
# 15                     Crew Collective & Cafe       45.502399
# 16                     Dominion Square Tavern       45.500405
# 17                               Cat's Corner       45.512893
# 18                                   Le Filet       45.517834
# 19            Cathédrale Marie-Reine-du-Monde       45.499614
# 20                              Tiffany & Co.       45.499782
# 21      St-Viateur Bagel (La Maison du Bagel)       45.522573
# 22                                Frank & Oak       45.499573
# 23  Salon de thé Cardinal / Cardinal Tea Room       45.524721
# 24                                  Noren　のれん       45.517026
# 25                                      Cadet       45.510260
# 26                            Moksha Yoga NDG       45.476606
# 27                           Milano Fruiterie       45.533055
# 28             Sofitel Montréal Le Carré Doré       45.501499
# 29                          Drawn & Quarterly       45.524748
# 30                         Boucherie Lawrence       45.524232
# 31                              Maison Boulud       45.500062
# 32                                Café Parvis       45.505817
# 33                                    Ta pies       45.517017
# 34                              Ferreira Café       45.500434
# 35                                 naada yoga       45.526864
# 36                             Café Santropol       45.515610
# 37                              SAQ Sélection       45.480446
# 38                                 Aux Vivres       45.521086
# 39                                       Jano       45.516066
# 40                             Marché Atwater       45.479790
# 41                              Louis Vuitton       45.497820
# 42                                     Leméac       45.518191
# 43                                     Empire       45.503952
# 44                              Bouillon Bilk       45.510845
# 45                       Moksha Yoga Montreal       45.516057
# 46                  The Ritz-Carlton Montréal       45.500191
# 47                        Papeterie Nota Bene       45.508571
# 48                        Pikolo Espresso Bar       45.508606
# 49                                       Loïc       45.470507
# 50                              Le Majestique       45.517445
# 51                            Le Vin Papillon       45.482763
# 52                          La Vieille Europe       45.515891
# 53                            MELK Bar à Café       45.498480
# 54                            Liverpool House       45.482893
#
#     Venue Longitude                 Venue Category  \
# 0        -73.595744                    Pizza Place
# 1        -73.589277                            Spa
# 2        -73.580203            Japanese Restaurant
# 3        -73.577394               Asian Restaurant
# 4        -73.577743                         Bakery
# 5        -73.577895                    Salad Place
# 6        -73.572849                           Café
# 7        -73.568213                    Pizza Place
# 8        -73.574817                            Gym
# 9        -73.584061                         Lounge
# 10       -73.613112       Mediterranean Restaurant
# 11       -73.574943                    Yoga Studio
# 12       -73.600442                           Café
# 13       -73.584088      Middle Eastern Restaurant
# 14       -73.584116      Middle Eastern Restaurant
# 15       -73.559202                           Café
# 16       -73.571636                      Gastropub
# 17       -73.570403                   Dance Studio
# 18       -73.588419             Seafood Restaurant
# 19       -73.569367                         Church
# 20       -73.578403                  Jewelry Store
# 21       -73.601878                     Bagel Shop
# 22       -73.574328                    Men's Store
# 23       -73.596464                       Tea Room
# 24       -73.582608            Japanese Restaurant
# 25       -73.564584                     Restaurant
# 26       -73.621498                    Yoga Studio
# 27       -73.614722                  Grocery Store
# 28       -73.577526                          Hotel
# 29       -73.604614                      Bookstore
# 30       -73.595292                  Deli / Bodega
# 31       -73.578324              French Restaurant
# 32       -73.569302                           Café
# 33       -73.589877          Australian Restaurant
# 34       -73.574060          Portuguese Restaurant
# 35       -73.597479                    Yoga Studio
# 36       -73.580611                           Café
# 37       -73.576695                   Liquor Store
# 38       -73.588506  Vegetarian / Vegan Restaurant
# 39       -73.577361          Portuguese Restaurant
# 40       -73.576775                         Market
# 41       -73.575306                       Boutique
# 42       -73.597304              French Restaurant
# 43       -73.571840            Sporting Goods Shop
# 44       -73.566017                     Restaurant
# 45       -73.577188                    Yoga Studio
# 46       -73.578127                          Hotel
# 47       -73.571672  Paper / Office Supplies Store
# 48       -73.571772                    Coffee Shop
# 49       -73.591000                         Lounge
# 50       -73.580368                     Restaurant
# 51       -73.575514                       Wine Bar
# 52       -73.576982                   Gourmet Shop
# 53       -73.572076                           Café
# 54       -73.575256                     Restaurant
#
#                                    Docking Station  Docking Station Latitude  \
# 0                             Maguire / St-Laurent                 45.524628
# 1                          Villeneuve / St-Laurent                 45.521342
# 2                          Ste-Catherine / St-Marc                 45.492897
# 3                                   Marché Atwater                 45.480208
# 4                                  Rivard / Rachel                 45.522278
# 5                        Crescent / de Maisonneuve                 45.498112
# 6                            Clark / Prince-Arthur                 45.513303
# 7                                  Square Phillips                 45.503738
# 8                            de Maisonneuve / Peel                 45.500951
# 9                           Vallières / St-Laurent                 45.518967
# 10                          Bloomfield / Van Horne                 45.522586
# 11                           de Maisonneuve / Peel                 45.500951
# 12                            Waverly / St-Viateur                 45.523856
# 13                           Laval / du Mont-Royal                 45.522365
# 14                          Vallières / St-Laurent                 45.518967
# 15                          St-Jacques / St-Pierre                 45.502786
# 16                 Metcalfe / du Square-Dorchester                 45.500208
# 17                                  Milton / Clark                 45.512541
# 18                  de l'Esplanade / du Mont-Royal                 45.518253
# 19                de la Cathédrale / René-Lévesque                 45.499191
# 20                     de la Montagne / Sherbrooke                 45.499745
# 21                       Jeanne-Mance / St-Viateur                 45.523026
# 22                         Stanley / Ste-Catherine                 45.499344
# 23                            Maguire / St-Laurent                 45.524628
# 24                                  Clark / Rachel                 45.517354
# 25  Métro St-Laurent (de Maisonneuve / St-Laurent)                 45.510660
# 26                          de Monkland / Girouard                 45.477107
# 27                             Mozart / St-Laurent                 45.533180
# 28                            Stanley / Sherbrooke                 45.501041
# 29                          Bernard / Jeanne-Mance                 45.524286
# 30                            Maguire / St-Laurent                 45.524628
# 31                     de la Montagne / Sherbrooke                 45.499745
# 32               de Maisonneuve / City Councillors                 45.506190
# 33                         du Mont-Royal / du Parc                 45.517000
# 34                           de Maisonneuve / Peel                 45.500951
# 35                       St-Dominique / St-Viateur                 45.526557
# 36                         Duluth / de l'Esplanade                 45.515092
# 37                                  Marché Atwater                 45.480208
# 38                         Villeneuve / St-Laurent                 45.521342
# 39                         Napoléon / St-Dominique                 45.516745
# 40                                  Marché Atwater                 45.480208
# 41                        Crescent / Ste-Catherine                 45.497092
# 42                               Querbes / Laurier                 45.517540
# 43          du President-Kennedy / Robert-Bourassa                 45.504627
# 44  Métro St-Laurent (de Maisonneuve / St-Laurent)                 45.510660
# 45                         Napoléon / St-Dominique                 45.516745
# 46                     de la Montagne / Sherbrooke                 45.499745
# 47                          Hutchison / Sherbrooke                 45.507810
# 48                          Hutchison / Sherbrooke                 45.507810
# 49                                  Palm / St-Remi                 45.470303
# 50                             Duluth / St-Laurent                 45.516876
# 51                           Duvernay / Charlevoix                 45.482040
# 52                                Roy / St-Laurent                 45.515616
# 53                                  Cypress / Peel                 45.499326
# 54                           Duvernay / Charlevoix                 45.482040
#
#     Docking Station Longitude  Distance (m)  Cluster
# 0                  -73.595811     10.583038        1
# 1                  -73.589419     12.969461       -1
# 2                  -73.580294     14.775945       -1
# 3                  -73.577599     22.883836        0
# 4                  -73.577591     25.170705       -1
# 5                  -73.577615     29.179987        4
# 6                  -73.572961     30.537609        3
# 7                  -73.568106     31.290720        2
# 8                  -73.574578     33.489149        5
# 9                  -73.583616     34.825866        6
# 10                 -73.612658     35.437825       -1
# 11                 -73.574578     36.641021        5
# 12                 -73.600127     37.976787        1
# 13                 -73.584146     38.484408       -1
# 14                 -73.583616     40.295889        6
# 15                 -73.559134     43.355469       -1
# 16                 -73.571138     44.564410        5
# 17                 -73.570677     44.618930        3
# 18                 -73.588338     47.009552       -1
# 19                 -73.569421     47.213863       -1
# 20                 -73.579034     49.303327        4
# 21                 -73.601840     50.538247        1
# 22                 -73.573760     51.069069        5
# 23                 -73.595811     51.894803        1
# 24                 -73.582129     52.149124        6
# 25                 -73.564970     53.678109       -1
# 26                 -73.621438     55.899685       -1
# 27                 -73.615440     57.657500       -1
# 28                 -73.577178     57.728634        4
# 29                 -73.604973     58.393492        1
# 30                 -73.595811     59.768675        1
# 31                 -73.579034     65.604786        4
# 32                 -73.569954     65.641906        2
# 33                 -73.589000     68.319860       -1
# 34                 -73.574578     70.226903        5
# 35                 -73.598276     70.886785        1
# 36                 -73.581142     70.912305        6
# 37                 -73.577599     75.253797        0
# 38                 -73.589419     76.649715       -1
# 39                 -73.577658     78.973763        7
# 40                 -73.577599     79.278863        0
# 41                 -73.575549     83.154334        5
# 42                 -73.597832     83.208770       -1
# 43                 -73.572325     84.019077        2
# 44                 -73.564970     84.116840        3
# 45                 -73.577658     84.827436        7
# 46                 -73.579034     86.358319        4
# 47                 -73.572080     90.423304        2
# 48                 -73.572080     91.680589        2
# 49                 -73.589848     92.611150       -1
# 50                 -73.579460     94.824154        6
# 51                 -73.574863     95.059025        0
# 52                 -73.575808     96.447711        7
# 53                 -73.571768     97.042175       -1
# 54                 -73.574863     99.697293        0

# %%
clustered['Cluster'].value_counts()
# Out:
# -1    16
#  1     7
#  5     6
#  2     5
#  6     5
#  4     5
#  0     5
#  7     3
#  3     3
# Name: Cluster, dtype: int64

# %% [markdown]
# The result of the k-means algorithm returns a total of 8 clusters. Unsurprisingly, we end up with several points being flagged as noise (where the cluster label is -1). Since the minimum number of points for a cluster was set to 3, isolated locations are categorized as noise.

# %% [markdown]
# Our goal is to identify the docking station locations with the most nearby venues. Therefore, it makes sense to drop the isolated locations (venues where *Cluster = -1*).

# %% [markdown]
# We'll continue to further explore the data to see how we can merger clusters/locations in a meaningful way.

# %% [markdown]
# Let's begin by dropping the isolated venues, where *Cluster=-1*.

# %%
clustered.drop(clustered[clustered['Cluster'] == -1 ].index, inplace=True)

# %%
clustered.sort_values(by=['Cluster'], inplace=True)
clustered.reset_index(drop=True, inplace=True)
clustered
# Out:
#                                         Venue  Venue Latitude  \
# 0                             Liverpool House       45.482893
# 1                              Satay Brothers       45.480061
# 2                             Le Vin Papillon       45.482763
# 3                              Marché Atwater       45.479790
# 4                               SAQ Sélection       45.480446
# 5                                  naada yoga       45.526864
# 6                           Drawn & Quarterly       45.524748
# 7   Salon de thé Cardinal / Cardinal Tea Room       45.524721
# 8       St-Viateur Bagel (La Maison du Bagel)       45.522573
# 9                             Pizzeria Magpie       45.524711
# 10                         Boucherie Lawrence       45.524232
# 11                              Café Olimpico       45.524116
# 12                        Pikolo Espresso Bar       45.508606
# 13                        Papeterie Nota Bene       45.508571
# 14                                Café Parvis       45.505817
# 15                                     Empire       45.503952
# 16                                Il Focolaio       45.504009
# 17                               Cat's Corner       45.512893
# 18                              Bouillon Bilk       45.510845
# 19                              Café Nocturne       45.513566
# 20                              Tiffany & Co.       45.499782
# 21                                    Mandy's       45.498286
# 22             Sofitel Montréal Le Carré Doré       45.501499
# 23                  The Ritz-Carlton Montréal       45.500191
# 24                              Maison Boulud       45.500062
# 25                              Louis Vuitton       45.497820
# 26                     Dominion Square Tavern       45.500405
# 27                           Club Sportif MAA       45.500700
# 28                              Ferreira Café       45.500434
# 29                                  Enso Yoga       45.500743
# 30                                Frank & Oak       45.499573
# 31                    Omnivore Comptoir Grill       45.519061
# 32                                    Darling       45.518995
# 33                                  Noren　のれん       45.517026
# 34                              Le Majestique       45.517445
# 35                             Café Santropol       45.515610
# 36                          La Vieille Europe       45.515891
# 37                       Moksha Yoga Montreal       45.516057
# 38                                       Jano       45.516066
#
#     Venue Longitude                 Venue Category  \
# 0        -73.575256                     Restaurant
# 1        -73.577394               Asian Restaurant
# 2        -73.575514                       Wine Bar
# 3        -73.576775                         Market
# 4        -73.576695                   Liquor Store
# 5        -73.597479                    Yoga Studio
# 6        -73.604614                      Bookstore
# 7        -73.596464                       Tea Room
# 8        -73.601878                     Bagel Shop
# 9        -73.595744                    Pizza Place
# 10       -73.595292                  Deli / Bodega
# 11       -73.600442                           Café
# 12       -73.571772                    Coffee Shop
# 13       -73.571672  Paper / Office Supplies Store
# 14       -73.569302                           Café
# 15       -73.571840            Sporting Goods Shop
# 16       -73.568213                    Pizza Place
# 17       -73.570403                   Dance Studio
# 18       -73.566017                     Restaurant
# 19       -73.572849                           Café
# 20       -73.578403                  Jewelry Store
# 21       -73.577895                    Salad Place
# 22       -73.577526                          Hotel
# 23       -73.578127                          Hotel
# 24       -73.578324              French Restaurant
# 25       -73.575306                       Boutique
# 26       -73.571636                      Gastropub
# 27       -73.574817                            Gym
# 28       -73.574060          Portuguese Restaurant
# 29       -73.574943                    Yoga Studio
# 30       -73.574328                    Men's Store
# 31       -73.584116      Middle Eastern Restaurant
# 32       -73.584061                         Lounge
# 33       -73.582608            Japanese Restaurant
# 34       -73.580368                     Restaurant
# 35       -73.580611                           Café
# 36       -73.576982                   Gourmet Shop
# 37       -73.577188                    Yoga Studio
# 38       -73.577361          Portuguese Restaurant
#
#                                    Docking Station  Docking Station Latitude  \
# 0                            Duvernay / Charlevoix                 45.482040
# 1                                   Marché Atwater                 45.480208
# 2                            Duvernay / Charlevoix                 45.482040
# 3                                   Marché Atwater                 45.480208
# 4                                   Marché Atwater                 45.480208
# 5                        St-Dominique / St-Viateur                 45.526557
# 6                           Bernard / Jeanne-Mance                 45.524286
# 7                             Maguire / St-Laurent                 45.524628
# 8                        Jeanne-Mance / St-Viateur                 45.523026
# 9                             Maguire / St-Laurent                 45.524628
# 10                            Maguire / St-Laurent                 45.524628
# 11                            Waverly / St-Viateur                 45.523856
# 12                          Hutchison / Sherbrooke                 45.507810
# 13                          Hutchison / Sherbrooke                 45.507810
# 14               de Maisonneuve / City Councillors                 45.506190
# 15          du President-Kennedy / Robert-Bourassa                 45.504627
# 16                                 Square Phillips                 45.503738
# 17                                  Milton / Clark                 45.512541
# 18  Métro St-Laurent (de Maisonneuve / St-Laurent)                 45.510660
# 19                           Clark / Prince-Arthur                 45.513303
# 20                     de la Montagne / Sherbrooke                 45.499745
# 21                       Crescent / de Maisonneuve                 45.498112
# 22                            Stanley / Sherbrooke                 45.501041
# 23                     de la Montagne / Sherbrooke                 45.499745
# 24                     de la Montagne / Sherbrooke                 45.499745
# 25                        Crescent / Ste-Catherine                 45.497092
# 26                 Metcalfe / du Square-Dorchester                 45.500208
# 27                           de Maisonneuve / Peel                 45.500951
# 28                           de Maisonneuve / Peel                 45.500951
# 29                           de Maisonneuve / Peel                 45.500951
# 30                         Stanley / Ste-Catherine                 45.499344
# 31                          Vallières / St-Laurent                 45.518967
# 32                          Vallières / St-Laurent                 45.518967
# 33                                  Clark / Rachel                 45.517354
# 34                             Duluth / St-Laurent                 45.516876
# 35                         Duluth / de l'Esplanade                 45.515092
# 36                                Roy / St-Laurent                 45.515616
# 37                         Napoléon / St-Dominique                 45.516745
# 38                         Napoléon / St-Dominique                 45.516745
#
#     Docking Station Longitude  Distance (m)  Cluster
# 0                  -73.574863     99.697293        0
# 1                  -73.577599     22.883836        0
# 2                  -73.574863     95.059025        0
# 3                  -73.577599     79.278863        0
# 4                  -73.577599     75.253797        0
# 5                  -73.598276     70.886785        1
# 6                  -73.604973     58.393492        1
# 7                  -73.595811     51.894803        1
# 8                  -73.601840     50.538247        1
# 9                  -73.595811     10.583038        1
# 10                 -73.595811     59.768675        1
# 11                 -73.600127     37.976787        1
# 12                 -73.572080     91.680589        2
# 13                 -73.572080     90.423304        2
# 14                 -73.569954     65.641906        2
# 15                 -73.572325     84.019077        2
# 16                 -73.568106     31.290720        2
# 17                 -73.570677     44.618930        3
# 18                 -73.564970     84.116840        3
# 19                 -73.572961     30.537609        3
# 20                 -73.579034     49.303327        4
# 21                 -73.577615     29.179987        4
# 22                 -73.577178     57.728634        4
# 23                 -73.579034     86.358319        4
# 24                 -73.579034     65.604786        4
# 25                 -73.575549     83.154334        5
# 26                 -73.571138     44.564410        5
# 27                 -73.574578     33.489149        5
# 28                 -73.574578     70.226903        5
# 29                 -73.574578     36.641021        5
# 30                 -73.573760     51.069069        5
# 31                 -73.583616     40.295889        6
# 32                 -73.583616     34.825866        6
# 33                 -73.582129     52.149124        6
# 34                 -73.579460     94.824154        6
# 35                 -73.581142     70.912305        6
# 36                 -73.575808     96.447711        7
# 37                 -73.577658     84.827436        7
# 38                 -73.577658     78.973763        7

# %% [markdown]
# Let's explore each individual cluster.

# %% [markdown]
# #### Cluster 1

# %%
cluster1 = clustered.loc[clustered['Cluster'] == 0]
cluster1
# Out:
#              Venue  Venue Latitude  Venue Longitude    Venue Category  \
# 0  Liverpool House       45.482893       -73.575256        Restaurant
# 1   Satay Brothers       45.480061       -73.577394  Asian Restaurant
# 2  Le Vin Papillon       45.482763       -73.575514          Wine Bar
# 3   Marché Atwater       45.479790       -73.576775            Market
# 4    SAQ Sélection       45.480446       -73.576695      Liquor Store
#
#          Docking Station  Docking Station Latitude  Docking Station Longitude  \
# 0  Duvernay / Charlevoix                 45.482040                 -73.574863
# 1         Marché Atwater                 45.480208                 -73.577599
# 2  Duvernay / Charlevoix                 45.482040                 -73.574863
# 3         Marché Atwater                 45.480208                 -73.577599
# 4         Marché Atwater                 45.480208                 -73.577599
#
#    Distance (m)  Cluster
# 0     99.697293        0
# 1     22.883836        0
# 2     95.059025        0
# 3     79.278863        0
# 4     75.253797        0

# %% [markdown]
# #### Cluster 2

# %%
cluster2 = clustered.loc[clustered['Cluster'] == 1]
cluster2
# Out:
#                                         Venue  Venue Latitude  \
# 5                                  naada yoga       45.526864
# 6                           Drawn & Quarterly       45.524748
# 7   Salon de thé Cardinal / Cardinal Tea Room       45.524721
# 8       St-Viateur Bagel (La Maison du Bagel)       45.522573
# 9                             Pizzeria Magpie       45.524711
# 10                         Boucherie Lawrence       45.524232
# 11                              Café Olimpico       45.524116
#
#     Venue Longitude Venue Category            Docking Station  \
# 5        -73.597479    Yoga Studio  St-Dominique / St-Viateur
# 6        -73.604614      Bookstore     Bernard / Jeanne-Mance
# 7        -73.596464       Tea Room       Maguire / St-Laurent
# 8        -73.601878     Bagel Shop  Jeanne-Mance / St-Viateur
# 9        -73.595744    Pizza Place       Maguire / St-Laurent
# 10       -73.595292  Deli / Bodega       Maguire / St-Laurent
# 11       -73.600442           Café       Waverly / St-Viateur
#
#     Docking Station Latitude  Docking Station Longitude  Distance (m)  Cluster
# 5                  45.526557                 -73.598276     70.886785        1
# 6                  45.524286                 -73.604973     58.393492        1
# 7                  45.524628                 -73.595811     51.894803        1
# 8                  45.523026                 -73.601840     50.538247        1
# 9                  45.524628                 -73.595811     10.583038        1
# 10                 45.524628                 -73.595811     59.768675        1
# 11                 45.523856                 -73.600127     37.976787        1

# %% [markdown]
# #### Cluster 3

# %%
cluster3 = clustered.loc[clustered['Cluster'] == 2]
cluster3
# Out:
#                   Venue  Venue Latitude  Venue Longitude  \
# 12  Pikolo Espresso Bar       45.508606       -73.571772
# 13  Papeterie Nota Bene       45.508571       -73.571672
# 14          Café Parvis       45.505817       -73.569302
# 15               Empire       45.503952       -73.571840
# 16          Il Focolaio       45.504009       -73.568213
#
#                    Venue Category                         Docking Station  \
# 12                    Coffee Shop                  Hutchison / Sherbrooke
# 13  Paper / Office Supplies Store                  Hutchison / Sherbrooke
# 14                           Café       de Maisonneuve / City Councillors
# 15            Sporting Goods Shop  du President-Kennedy / Robert-Bourassa
# 16                    Pizza Place                         Square Phillips
#
#     Docking Station Latitude  Docking Station Longitude  Distance (m)  Cluster
# 12                 45.507810                 -73.572080     91.680589        2
# 13                 45.507810                 -73.572080     90.423304        2
# 14                 45.506190                 -73.569954     65.641906        2
# 15                 45.504627                 -73.572325     84.019077        2
# 16                 45.503738                 -73.568106     31.290720        2

# %% [markdown]
# #### Cluster 4

# %%
cluster4 = clustered.loc[clustered['Cluster'] == 3]
cluster4
# Out:
#             Venue  Venue Latitude  Venue Longitude Venue Category  \
# 17   Cat's Corner       45.512893       -73.570403   Dance Studio
# 18  Bouillon Bilk       45.510845       -73.566017     Restaurant
# 19  Café Nocturne       45.513566       -73.572849           Café
#
#                                    Docking Station  Docking Station Latitude  \
# 17                                  Milton / Clark                 45.512541
# 18  Métro St-Laurent (de Maisonneuve / St-Laurent)                 45.510660
# 19                           Clark / Prince-Arthur                 45.513303
#
#     Docking Station Longitude  Distance (m)  Cluster
# 17                 -73.570677     44.618930        3
# 18                 -73.564970     84.116840        3
# 19                 -73.572961     30.537609        3

# %% [markdown]
# #### Cluster 5

# %%
cluster5 = clustered.loc[clustered['Cluster'] == 4]
cluster5
# Out:
#                              Venue  Venue Latitude  Venue Longitude  \
# 20                   Tiffany & Co.       45.499782       -73.578403
# 21                         Mandy's       45.498286       -73.577895
# 22  Sofitel Montréal Le Carré Doré       45.501499       -73.577526
# 23       The Ritz-Carlton Montréal       45.500191       -73.578127
# 24                   Maison Boulud       45.500062       -73.578324
#
#        Venue Category              Docking Station  Docking Station Latitude  \
# 20      Jewelry Store  de la Montagne / Sherbrooke                 45.499745
# 21        Salad Place    Crescent / de Maisonneuve                 45.498112
# 22              Hotel         Stanley / Sherbrooke                 45.501041
# 23              Hotel  de la Montagne / Sherbrooke                 45.499745
# 24  French Restaurant  de la Montagne / Sherbrooke                 45.499745
#
#     Docking Station Longitude  Distance (m)  Cluster
# 20                 -73.579034     49.303327        4
# 21                 -73.577615     29.179987        4
# 22                 -73.577178     57.728634        4
# 23                 -73.579034     86.358319        4
# 24                 -73.579034     65.604786        4

# %% [markdown]
# #### Cluster 6

# %%
cluster6 = clustered.loc[clustered['Cluster'] == 5]
cluster6
# Out:
#                      Venue  Venue Latitude  Venue Longitude  \
# 25           Louis Vuitton       45.497820       -73.575306
# 26  Dominion Square Tavern       45.500405       -73.571636
# 27        Club Sportif MAA       45.500700       -73.574817
# 28           Ferreira Café       45.500434       -73.574060
# 29               Enso Yoga       45.500743       -73.574943
# 30             Frank & Oak       45.499573       -73.574328
#
#            Venue Category                  Docking Station  \
# 25               Boutique         Crescent / Ste-Catherine
# 26              Gastropub  Metcalfe / du Square-Dorchester
# 27                    Gym            de Maisonneuve / Peel
# 28  Portuguese Restaurant            de Maisonneuve / Peel
# 29            Yoga Studio            de Maisonneuve / Peel
# 30            Men's Store          Stanley / Ste-Catherine
#
#     Docking Station Latitude  Docking Station Longitude  Distance (m)  Cluster
# 25                 45.497092                 -73.575549     83.154334        5
# 26                 45.500208                 -73.571138     44.564410        5
# 27                 45.500951                 -73.574578     33.489149        5
# 28                 45.500951                 -73.574578     70.226903        5
# 29                 45.500951                 -73.574578     36.641021        5
# 30                 45.499344                 -73.573760     51.069069        5

# %% [markdown]
# #### Cluster 7

# %%
cluster7 = clustered.loc[clustered['Cluster'] == 6]
cluster7
# Out:
#                       Venue  Venue Latitude  Venue Longitude  \
# 31  Omnivore Comptoir Grill       45.519061       -73.584116
# 32                  Darling       45.518995       -73.584061
# 33                Noren　のれん       45.517026       -73.582608
# 34            Le Majestique       45.517445       -73.580368
# 35           Café Santropol       45.515610       -73.580611
#
#                Venue Category          Docking Station  \
# 31  Middle Eastern Restaurant   Vallières / St-Laurent
# 32                     Lounge   Vallières / St-Laurent
# 33        Japanese Restaurant           Clark / Rachel
# 34                 Restaurant      Duluth / St-Laurent
# 35                       Café  Duluth / de l'Esplanade
#
#     Docking Station Latitude  Docking Station Longitude  Distance (m)  Cluster
# 31                 45.518967                 -73.583616     40.295889        6
# 32                 45.518967                 -73.583616     34.825866        6
# 33                 45.517354                 -73.582129     52.149124        6
# 34                 45.516876                 -73.579460     94.824154        6
# 35                 45.515092                 -73.581142     70.912305        6

# %% [markdown]
# #### Cluster 8

# %%
cluster8 = clustered.loc[clustered['Cluster'] == 7]
cluster8
# Out:
#                    Venue  Venue Latitude  Venue Longitude  \
# 36     La Vieille Europe       45.515891       -73.576982
# 37  Moksha Yoga Montreal       45.516057       -73.577188
# 38                  Jano       45.516066       -73.577361
#
#            Venue Category          Docking Station  Docking Station Latitude  \
# 36           Gourmet Shop         Roy / St-Laurent                 45.515616
# 37            Yoga Studio  Napoléon / St-Dominique                 45.516745
# 38  Portuguese Restaurant  Napoléon / St-Dominique                 45.516745
#
#     Docking Station Longitude  Distance (m)  Cluster
# 36                 -73.575808     96.447711        7
# 37                 -73.577658     84.827436        7
# 38                 -73.577658     78.973763        7

# %%
# create map of stations and nearby venues using latitude and longitude values
cluster_map = folium.Map(location=[mtl_latitude, mtl_longitude], zoom_start=13)

s_name = clustered['Docking Station']
s_lat = clustered['Docking Station Latitude']
s_lng = clustered['Docking Station Longitude']

# add markers to map to visualize the Bixi docking stations
for lat, lng, label in zip(s_lat, s_lng, s_name):
    label = folium.Popup(label, parse_html=True)
    folium.Marker([lat, lng],popup=label).add_to(cluster_map)

    
# add markers to map to visualize the trending venues in Montreal, by cluster

# cluster 1, in red
clus1_ven = clustered.loc[0:4,'Venue']
clus1_lat = clustered.loc[0:4,'Venue Latitude']
clus1_lng = clustered.loc[0:4,'Venue Longitude']
for lat, lng, label in zip(clus1_lat, clus1_lng, clus1_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='red',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map)  

# cluster 2, in yellow
clus2_ven = clustered.loc[5:11,'Venue']
clus2_lat = clustered.loc[5:11,'Venue Latitude']
clus2_lng = clustered.loc[5:11,'Venue Longitude']
for lat, lng, label in zip(clus2_lat, clus2_lng, clus2_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='yellow',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map) 

# cluster 3, in grey
clus3_ven = clustered.loc[12:16,'Venue']
clus3_lat = clustered.loc[12:16,'Venue Latitude']
clus3_lng = clustered.loc[12:16,'Venue Longitude']
for lat, lng, label in zip(clus3_lat, clus3_lng, clus3_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='grey',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map) 

# cluster 4, in green
clus4_ven = clustered.loc[17:19,'Venue']
clus4_lat = clustered.loc[17:19,'Venue Latitude']
clus4_lng = clustered.loc[17:19,'Venue Longitude']
for lat, lng, label in zip(clus4_lat, clus4_lng, clus4_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='green',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map) 
        
# cluster 5, in purple
clus5_ven = clustered.loc[20:24,'Venue']
clus5_lat = clustered.loc[20:24,'Venue Latitude']
clus5_lng = clustered.loc[20:24,'Venue Longitude']
for lat, lng, label in zip(clus5_lat, clus5_lng, clus5_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='purple',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map) 

# cluster 6, in blue
clus6_ven = clustered.loc[25:30,'Venue']
clus6_lat = clustered.loc[25:30,'Venue Latitude']
clus6_lng = clustered.loc[25:30,'Venue Longitude']
for lat, lng, label in zip(clus6_lat, clus6_lng, clus6_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='blue',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map) 
        
# cluster 7, in pink
clus7_ven = clustered.loc[31:35,'Venue']
clus7_lat = clustered.loc[31:35,'Venue Latitude']
clus7_lng = clustered.loc[31:35,'Venue Longitude']
for lat, lng, label in zip(clus7_lat, clus7_lng, clus7_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='pink',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map) 
        
# cluster 8, in orange
clus8_ven = clustered.loc[36:38,'Venue']
clus8_lat = clustered.loc[36:38,'Venue Latitude']
clus8_lng = clustered.loc[36:38,'Venue Longitude']
for lat, lng, label in zip(clus8_lat, clus8_lng, clus8_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='orange',fill=True,fill_opacity=0.7,parse_html=False).add_to(cluster_map) 

cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## IV. Results and Discussion

# %% [markdown]
# Visualizing the clusters on the map by color makes it easy to select the optimal station for the cluster. We can immediately notice that there are several docking stations in one cluster, often right next to one venue. However, we are looking for only one docking station per cluster as it is more convenient for a tourist to be parking the bike in one docking station, and walking to the nearby venues.

# %% [markdown]
# We will select the station that is most central to each venue in the cluster, or the station with the most venues nearby.

# %% [markdown]
# According to the map, the following stations seems to be the most representative for each cluster:
#
# - *Cluster 1*: **Marche Atwater**, since it has 3 out the 5 venues nearby.
# - *Cluster 2*: **Waverly/St-Viateur**, since it seems to be the most central in that cluster.
# - *Cluster 3*: **Square Philips**, since it seems to be the most central in that cluster.
# - *Cluster 4*: **Milton/Clark**, since it seems to be the most central in that cluster.
# - *Cluster 5*: **de la Montagne/Sherbrooke**, since it seems to be the most central in that cluster and has the most venues nearby.
# - *Cluster 6*: **Stanley/St-Catherine**, since it seems to be the most central in that cluster.
# - *Cluster 7*: **Clark/Rachel**, since it seems to be the most central in that cluster.
# - *Cluster 8*: **Napoléon / St-Dominique**, it seems to be the nearest to all venues in that cluster.

# %% [markdown]
# Now let's clean up our dataframe to reflect these results and plot them on the map.

# %%
cluster1['Docking Station']='Marché Atwater'
cluster1['Docking Station Latitude']=45.480208
cluster1['Docking Station Longitude']=-73.577599
i=0
for i in range(i, len(cluster1['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster1.iat[i,1]
    lng1 = cluster1.iat[i,2]
    lat2 = cluster1.iat[i,5]
    lng2 = cluster1.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster1.set_value(i,'Distance (m)',d)
    i=i+1

cluster2['Docking Station']='Waverly / St-Viateur'
cluster2['Docking Station Latitude']=45.523856
cluster2['Docking Station Longitude']=-73.600127
i=5
for i in range(i, len(cluster2['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster2.iat[i,1]
    lng1 = cluster2.iat[i,2]
    lat2 = cluster2.iat[i,5]
    lng2 = cluster2.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster2.set_value(i,'Distance (m)',d)
    i=i+1

cluster3['Docking Station']='Square Phillips'
cluster3['Docking Station Latitude']=45.503738
cluster3['Docking Station Longitude']=-73.568106
i=12
for i in range(i, len(cluster3['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster3.iat[i,1]
    lng1 = cluster3.iat[i,2]
    lat2 = cluster3.iat[i,5]
    lng2 = cluster3.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster3.set_value(i,'Distance (m)',d)
    i=i+1

cluster4['Docking Station']='Milton / Clark'
cluster4['Docking Station Latitude']=45.512541
cluster4['Docking Station Longitude']=-73.570677
i=17
for i in range(i, len(cluster4['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster4.iat[i,1]
    lng1 = cluster4.iat[i,2]
    lat2 = cluster4.iat[i,5]
    lng2 = cluster4.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster4.set_value(i,'Distance (m)',d)
    i=i+1

cluster5['Docking Station']='de la Montagne / Sherbrooke'
cluster5['Docking Station Latitude']=45.499745
cluster5['Docking Station Longitude']=-73.579034
i=20
for i in range(i, len(cluster5['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster5.iat[i,1]
    lng1 = cluster5.iat[i,2]
    lat2 = cluster5.iat[i,5]
    lng2 = cluster5.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster5.set_value(i,'Distance (m)',d)
    i=i+1
    
cluster6['Docking Station']='Stanley / Ste-Catherine'
cluster6['Docking Station Latitude']=45.499344
cluster6['Docking Station Longitude']=-73.573760
i=25
for i in range(i, len(cluster6['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster6.iat[i,1]
    lng1 = cluster6.iat[i,2]
    lat2 = cluster6.iat[i,5]
    lng2 = cluster6.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster6.set_value(i,'Distance (m)',d)
    i=i+1

cluster7['Docking Station']='Clark / Rachel'
cluster7['Docking Station Latitude']=45.517354
cluster7['Docking Station Longitude']=-73.582129
i=31
for i in range(i, len(cluster7['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster7.iat[i,1]
    lng1 = cluster7.iat[i,2]
    lat2 = cluster7.iat[i,5]
    lng2 = cluster7.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster7.set_value(i,'Distance (m)',d)
    i=i+1

cluster8['Docking Station']='Napoléon / St-Dominique'
cluster8['Docking Station Latitude']=45.516745
cluster8['Docking Station Longitude']=-73.577658
i=36
for i in range(i, len(cluster8['Cluster'])): # iterates all rows in the cluster and replace distance with new value
    lat1 = cluster8.iat[i,1]
    lng1 = cluster8.iat[i,2]
    lat2 = cluster8.iat[i,5]
    lng2 = cluster8.iat[i,6]
    d = haversine(lng1, lat1, lng2, lat2)
    cluster8.set_value(i,'Distance (m)',d)
    i=i+1
    
final = pd.concat([cluster1,cluster2,cluster3,cluster4,cluster5,cluster6,cluster7,cluster8], axis=0)
final
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                         Venue  Venue Latitude  \
# 0                             Liverpool House       45.482893
# 1                              Satay Brothers       45.480061
# 2                             Le Vin Papillon       45.482763
# 3                              Marché Atwater       45.479790
# 4                               SAQ Sélection       45.480446
# 5                                  naada yoga       45.526864
# 6                           Drawn & Quarterly       45.524748
# 7   Salon de thé Cardinal / Cardinal Tea Room       45.524721
# 8       St-Viateur Bagel (La Maison du Bagel)       45.522573
# 9                             Pizzeria Magpie       45.524711
# 10                         Boucherie Lawrence       45.524232
# 11                              Café Olimpico       45.524116
# 12                        Pikolo Espresso Bar       45.508606
# 13                        Papeterie Nota Bene       45.508571
# 14                                Café Parvis       45.505817
# 15                                     Empire       45.503952
# 16                                Il Focolaio       45.504009
# 17                               Cat's Corner       45.512893
# 18                              Bouillon Bilk       45.510845
# 19                              Café Nocturne       45.513566
# 20                              Tiffany & Co.       45.499782
# 21                                    Mandy's       45.498286
# 22             Sofitel Montréal Le Carré Doré       45.501499
# 23                  The Ritz-Carlton Montréal       45.500191
# 24                              Maison Boulud       45.500062
# 25                              Louis Vuitton       45.497820
# 26                     Dominion Square Tavern       45.500405
# 27                           Club Sportif MAA       45.500700
# 28                              Ferreira Café       45.500434
# 29                                  Enso Yoga       45.500743
# 30                                Frank & Oak       45.499573
# 31                    Omnivore Comptoir Grill       45.519061
# 32                                    Darling       45.518995
# 33                                  Noren　のれん       45.517026
# 34                              Le Majestique       45.517445
# 35                             Café Santropol       45.515610
# 36                          La Vieille Europe       45.515891
# 37                       Moksha Yoga Montreal       45.516057
# 38                                       Jano       45.516066
#
#     Venue Longitude                 Venue Category  \
# 0        -73.575256                     Restaurant
# 1        -73.577394               Asian Restaurant
# 2        -73.575514                       Wine Bar
# 3        -73.576775                         Market
# 4        -73.576695                   Liquor Store
# 5        -73.597479                    Yoga Studio
# 6        -73.604614                      Bookstore
# 7        -73.596464                       Tea Room
# 8        -73.601878                     Bagel Shop
# 9        -73.595744                    Pizza Place
# 10       -73.595292                  Deli / Bodega
# 11       -73.600442                           Café
# 12       -73.571772                    Coffee Shop
# 13       -73.571672  Paper / Office Supplies Store
# 14       -73.569302                           Café
# 15       -73.571840            Sporting Goods Shop
# 16       -73.568213                    Pizza Place
# 17       -73.570403                   Dance Studio
# 18       -73.566017                     Restaurant
# 19       -73.572849                           Café
# 20       -73.578403                  Jewelry Store
# 21       -73.577895                    Salad Place
# 22       -73.577526                          Hotel
# 23       -73.578127                          Hotel
# 24       -73.578324              French Restaurant
# 25       -73.575306                       Boutique
# 26       -73.571636                      Gastropub
# 27       -73.574817                            Gym
# 28       -73.574060          Portuguese Restaurant
# 29       -73.574943                    Yoga Studio
# 30       -73.574328                    Men's Store
# 31       -73.584116      Middle Eastern Restaurant
# 32       -73.584061                         Lounge
# 33       -73.582608            Japanese Restaurant
# 34       -73.580368                     Restaurant
# 35       -73.580611                           Café
# 36       -73.576982                   Gourmet Shop
# 37       -73.577188                    Yoga Studio
# 38       -73.577361          Portuguese Restaurant
#
#                 Docking Station  Docking Station Latitude  \
# 0                Marché Atwater                 45.480208
# 1                Marché Atwater                 45.480208
# 2                Marché Atwater                 45.480208
# 3                Marché Atwater                 45.480208
# 4                Marché Atwater                 45.480208
# 5          Waverly / St-Viateur                 45.523856
# 6          Waverly / St-Viateur                 45.523856
# 7          Waverly / St-Viateur                 45.523856
# 8          Waverly / St-Viateur                 45.523856
# 9          Waverly / St-Viateur                 45.523856
# 10         Waverly / St-Viateur                 45.523856
# 11         Waverly / St-Viateur                 45.523856
# 12              Square Phillips                 45.503738
# 13              Square Phillips                 45.503738
# 14              Square Phillips                 45.503738
# 15              Square Phillips                 45.503738
# 16              Square Phillips                 45.503738
# 17               Milton / Clark                 45.512541
# 18               Milton / Clark                 45.512541
# 19               Milton / Clark                 45.512541
# 20  de la Montagne / Sherbrooke                 45.499745
# 21  de la Montagne / Sherbrooke                 45.499745
# 22  de la Montagne / Sherbrooke                 45.499745
# 23  de la Montagne / Sherbrooke                 45.499745
# 24  de la Montagne / Sherbrooke                 45.499745
# 25      Stanley / Ste-Catherine                 45.499344
# 26      Stanley / Ste-Catherine                 45.499344
# 27      Stanley / Ste-Catherine                 45.499344
# 28      Stanley / Ste-Catherine                 45.499344
# 29      Stanley / Ste-Catherine                 45.499344
# 30      Stanley / Ste-Catherine                 45.499344
# 31               Clark / Rachel                 45.517354
# 32               Clark / Rachel                 45.517354
# 33               Clark / Rachel                 45.517354
# 34               Clark / Rachel                 45.517354
# 35               Clark / Rachel                 45.517354
# 36      Napoléon / St-Dominique                 45.516745
# 37      Napoléon / St-Dominique                 45.516745
# 38      Napoléon / St-Dominique                 45.516745
#
#     Docking Station Longitude  Distance (m)  Cluster
# 0                  -73.577599    350.005588        0
# 1                  -73.577599     22.885800        0
# 2                  -73.577599    327.262320        0
# 3                  -73.577599     79.287258        0
# 4                  -73.577599     75.289608        0
# 5                  -73.600127    378.948298        1
# 6                  -73.600127     37.964041        1
# 7                  -73.600127     51.894803        1
# 8                  -73.600127     50.538247        1
# 9                  -73.600127     10.583038        1
# 10                 -73.600127     59.768675        1
# 11                 -73.600127     37.976787        1
# 12                 -73.568106     91.680589        2
# 13                 -73.568106     90.423304        2
# 14                 -73.568106     65.641906        2
# 15                 -73.568106     84.019077        2
# 16                 -73.568106     31.290720        2
# 17                 -73.570677     44.618930        3
# 18                 -73.570677     84.116840        3
# 19                 -73.570677     30.537609        3
# 20                 -73.579034     49.303327        4
# 21                 -73.579034     29.179987        4
# 22                 -73.579034     57.728634        4
# 23                 -73.579034     86.358319        4
# 24                 -73.579034     65.604786        4
# 25                 -73.573760     83.154334        5
# 26                 -73.573760     44.564410        5
# 27                 -73.573760     33.489149        5
# 28                 -73.573760     70.226903        5
# 29                 -73.573760     36.641021        5
# 30                 -73.573760     51.069069        5
# 31                 -73.582129     40.295889        6
# 32                 -73.582129     34.825866        6
# 33                 -73.582129     52.149124        6
# 34                 -73.582129     94.824154        6
# 35                 -73.582129     70.912305        6
# 36                 -73.577658     96.447711        7
# 37                 -73.577658     84.827436        7
# 38                 -73.577658     78.973763        7

# %%
# create map of stations and nearby venues using latitude and longitude values
final_map = folium.Map(location=[mtl_latitude, mtl_longitude], zoom_start=13)

s_name = final['Docking Station']
s_lat = final['Docking Station Latitude']
s_lng = final['Docking Station Longitude']

# add markers to map to visualize the Bixi docking stations
for lat, lng, label in zip(s_lat, s_lng, s_name):
    label = folium.Popup(label, parse_html=True)
    folium.Marker([lat, lng],popup=label).add_to(final_map)

    
# add markers to map to visualize the trending venues in Montreal, by cluster

# cluster 1, in red
clus1_ven = final.loc[0:4,'Venue']
clus1_lat = final.loc[0:4,'Venue Latitude']
clus1_lng = final.loc[0:4,'Venue Longitude']
for lat, lng, label in zip(clus1_lat, clus1_lng, clus1_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='red',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map)  

# cluster 2, in yellow
clus2_ven = final.loc[5:11,'Venue']
clus2_lat = final.loc[5:11,'Venue Latitude']
clus2_lng = final.loc[5:11,'Venue Longitude']
for lat, lng, label in zip(clus2_lat, clus2_lng, clus2_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='yellow',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map) 

# cluster 3, in grey
clus3_ven = final.loc[12:16,'Venue']
clus3_lat = final.loc[12:16,'Venue Latitude']
clus3_lng = final.loc[12:16,'Venue Longitude']
for lat, lng, label in zip(clus3_lat, clus3_lng, clus3_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='grey',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map) 

# cluster 4, in green
clus4_ven = final.loc[17:19,'Venue']
clus4_lat = final.loc[17:19,'Venue Latitude']
clus4_lng = final.loc[17:19,'Venue Longitude']
for lat, lng, label in zip(clus4_lat, clus4_lng, clus4_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='green',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map) 
        
# cluster 5, in purple
clus5_ven = final.loc[20:24,'Venue']
clus5_lat = final.loc[20:24,'Venue Latitude']
clus5_lng = final.loc[20:24,'Venue Longitude']
for lat, lng, label in zip(clus5_lat, clus5_lng, clus5_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='purple',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map) 

# cluster 6, in blue
clus6_ven = final.loc[25:30,'Venue']
clus6_lat = final.loc[25:30,'Venue Latitude']
clus6_lng = final.loc[25:30,'Venue Longitude']
for lat, lng, label in zip(clus6_lat, clus6_lng, clus6_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='blue',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map) 
        
# cluster 7, in pink
clus7_ven = final.loc[31:35,'Venue']
clus7_lat = final.loc[31:35,'Venue Latitude']
clus7_lng = final.loc[31:35,'Venue Longitude']
for lat, lng, label in zip(clus7_lat, clus7_lng, clus7_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='pink',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map) 
        
# cluster 8, in orange
clus8_ven = final.loc[36:38,'Venue']
clus8_lat = final.loc[36:38,'Venue Latitude']
clus8_lng = final.loc[36:38,'Venue Longitude']
for lat, lng, label in zip(clus8_lat, clus8_lng, clus8_ven):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker([lat,lng],radius=5,popup=label,color='orange',fill=True,fill_opacity=0.7,parse_html=False).add_to(final_map) 

final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's simplify our final dataframe to list the most relevant information.

# %%
final1 = final[['Docking Station','Venue','Venue Category','Distance (m)']]
final1.groupby(['Docking Station','Venue','Venue Category']).mean()
final1
# Out:
#                 Docking Station                                      Venue  \
# 0                Marché Atwater                            Liverpool House
# 1                Marché Atwater                             Satay Brothers
# 2                Marché Atwater                            Le Vin Papillon
# 3                Marché Atwater                             Marché Atwater
# 4                Marché Atwater                              SAQ Sélection
# 5          Waverly / St-Viateur                                 naada yoga
# 6          Waverly / St-Viateur                          Drawn & Quarterly
# 7          Waverly / St-Viateur  Salon de thé Cardinal / Cardinal Tea Room
# 8          Waverly / St-Viateur      St-Viateur Bagel (La Maison du Bagel)
# 9          Waverly / St-Viateur                            Pizzeria Magpie
# 10         Waverly / St-Viateur                         Boucherie Lawrence
# 11         Waverly / St-Viateur                              Café Olimpico
# 12              Square Phillips                        Pikolo Espresso Bar
# 13              Square Phillips                        Papeterie Nota Bene
# 14              Square Phillips                                Café Parvis
# 15              Square Phillips                                     Empire
# 16              Square Phillips                                Il Focolaio
# 17               Milton / Clark                               Cat's Corner
# 18               Milton / Clark                              Bouillon Bilk
# 19               Milton / Clark                              Café Nocturne
# 20  de la Montagne / Sherbrooke                              Tiffany & Co.
# 21  de la Montagne / Sherbrooke                                    Mandy's
# 22  de la Montagne / Sherbrooke             Sofitel Montréal Le Carré Doré
# 23  de la Montagne / Sherbrooke                  The Ritz-Carlton Montréal
# 24  de la Montagne / Sherbrooke                              Maison Boulud
# 25      Stanley / Ste-Catherine                              Louis Vuitton
# 26      Stanley / Ste-Catherine                     Dominion Square Tavern
# 27      Stanley / Ste-Catherine                           Club Sportif MAA
# 28      Stanley / Ste-Catherine                              Ferreira Café
# 29      Stanley / Ste-Catherine                                  Enso Yoga
# 30      Stanley / Ste-Catherine                                Frank & Oak
# 31               Clark / Rachel                    Omnivore Comptoir Grill
# 32               Clark / Rachel                                    Darling
# 33               Clark / Rachel                                  Noren　のれん
# 34               Clark / Rachel                              Le Majestique
# 35               Clark / Rachel                             Café Santropol
# 36      Napoléon / St-Dominique                          La Vieille Europe
# 37      Napoléon / St-Dominique                       Moksha Yoga Montreal
# 38      Napoléon / St-Dominique                                       Jano
#
#                    Venue Category  Distance (m)
# 0                      Restaurant    350.005588
# 1                Asian Restaurant     22.885800
# 2                        Wine Bar    327.262320
# 3                          Market     79.287258
# 4                    Liquor Store     75.289608
# 5                     Yoga Studio    378.948298
# 6                       Bookstore     37.964041
# 7                        Tea Room     51.894803
# 8                      Bagel Shop     50.538247
# 9                     Pizza Place     10.583038
# 10                  Deli / Bodega     59.768675
# 11                           Café     37.976787
# 12                    Coffee Shop     91.680589
# 13  Paper / Office Supplies Store     90.423304
# 14                           Café     65.641906
# 15            Sporting Goods Shop     84.019077
# 16                    Pizza Place     31.290720
# 17                   Dance Studio     44.618930
# 18                     Restaurant     84.116840
# 19                           Café     30.537609
# 20                  Jewelry Store     49.303327
# 21                    Salad Place     29.179987
# 22                          Hotel     57.728634
# 23                          Hotel     86.358319
# 24              French Restaurant     65.604786
# 25                       Boutique     83.154334
# 26                      Gastropub     44.564410
# 27                            Gym     33.489149
# 28          Portuguese Restaurant     70.226903
# 29                    Yoga Studio     36.641021
# 30                    Men's Store     51.069069
# 31      Middle Eastern Restaurant     40.295889
# 32                         Lounge     34.825866
# 33            Japanese Restaurant     52.149124
# 34                     Restaurant     94.824154
# 35                           Café     70.912305
# 36                   Gourmet Shop     96.447711
# 37                    Yoga Studio     84.827436
# 38          Portuguese Restaurant     78.973763

# %%
df_locations.to_excel("capstone.xlsx", sheet_name='df_locations')
filtered_locations.to_excel("capstone.xlsx", sheet_name='filtered_locations')
clustered.to_excel("capstone.xlsx", sheet_name='clustered')
final.to_excel("capstone.xlsx", sheet_name='final')
final1.to_excel("capstone.xlsx", sheet_name='final1')

# %% [markdown]
# ## VI. Conclusion

# %% [markdown]
# The objective of this report was to analyse the trending venues in Montreal, and locate the nearest Bixi docking station, which would maximize a tourists time for visiting Montreal. Whilst exploring the data, it was clear that there are many Bixi docking stations around the city (615), a lot more than Foursquare had returned trending venues (100).

# %% [markdown]
# Of course, we could have fetched the trending venues around each docking station, but Foursquare would have returned too many values, which would have been filtered anyway in order to keep the most relevant. Choosing to stick with the top 100 trending venues in the city gave a more accurate representation of what actually is trending in the city, and not just because it is located near a docking station.

# %% [markdown]
# Using Folium to visualize the results at every step, meaning every time the data was filtered to keep the most relevant, gave insightful information about the venues and station locations. Since the objective of this project was to determine the docking stations with the most venues nearby, it made sense to use k-means algorithm with HBSCAN to cluster the trending venues by location. By setting the cluster minimum to 3 allowed this method determined the clusters of venues containing at least 3 venues next to one another. From that point on it would be easy to determine one docking station by cluster, simply by visualizing the venues by cluster, as well as the nearest stations within each cluster.

# %% [markdown]
# The final result yields a total of 8 clusters of trending venues, from a total of 39 unique venues, and a docking station within each cluster.
